# %%
import nltk,sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import nltk.data
import csv
from nltk.stem.porter import *
pd.options.mode.chained_assignment = None
from sklearn.preprocessing import LabelEncoder
from numpy import array as arr
from numpy import argmax

# %%
#Read data from dataset
#data = pd.read_csv("mbti_1.csv") 
#shortdata=data.iloc[:,-1]
arr=[]
file = open("downloaded1.csv",'rt')
samples=csv.reader(file)
c=0
for i in samples:
    c+=1
    
    if c==2:
        x=i[1]
        break

for i in samples:
    if i[1]!=x:
        arr.append(i)


df=pd.DataFrame(data=arr,columns=("types","posts"))
print(len(df.columns))
print(df)
#shortdata=shortdata.head()
#shortdata1=data.iloc[0:5,0]
print('-----Data-------')
#print(shortdata)
# Out:
# 2
#          types                                              posts
# 0     negative  Iranian general says Israel's Iron Dome can't ...
# 1     positive  with J Davlar 11th. Main rivals are team Polan...
# 2     negative  Talking about ACT's &amp;&amp; SAT's, deciding...
# 3     negative  They may have a SuperBowl in Dallas, but Dalla...
# 4      neutral  Im bringing the monster load of candy tomorrow...
# 5      neutral  Apple software, retail chiefs out in overhaul:...
# 6     positive  @oluoch @victor_otti @kunjand I just watched i...
# 7      neutral  #Livewire Nadal confirmed for Mexican Open in ...
# 8     positive  @MsSheLahY I didnt want to just pop up... but ...
# 9      neutral  @Alyoup005 @addicted2haley hmmmm  November is ...
# 10     neutral  #Iran US delisting MKO from global terrorists ...
# 11    positive  Good Morning Becky ! Thursday is going to be F...
# 12     neutral  Expect light-moderate rains over E. Visayas; C...
# 13    positive  One ticket left for the @49ers game tomorrow! ...
# 14    negative  AFC away fans on Saturday. All this stuff abou...
# 15     neutral  Game 1 of the NLCS and a rematch of the NFC Ch...
# 16    positive  Never start working on your dreams and goals t...
# 17    positive  @TheFFAddict I had Vick and Flacco, needed an ...
# 18    positive  Looks like Andy the Android may have had a lit...
# 19    positive  @APGPhoto oooh nice .. Tis tempting to go up t...
# 20     neutral  BLACK FRIDAY Huge Saving Aerial View of a City...
# 21    negative  @MelmurMel @PBandJenelley_1 @vl_delp_ham_ Jene...
# 22     neutral  Mohamed Morsi, Egypt's Muslim Brotherhood pres...
# 23     neutral  C'mon Avila! You just got tagged out by a guy ...
# 24     neutral  At the first Grammy Awards, held on 4 May 1959...
# 25    positive  @JennetteMcHevan I have studied all day but to...
# 26    positive  Good morning Thursday. "Life is fragile. We're...
# 27    positive  #Twitition Mcfly come back to Argentina but th...
# 28     neutral  #Broncos Peyton Manning named AFC Offensive Pl...
# 29     neutral  @TooZany is bringing out Kendrick Lamar the 6t...
# ...        ...                                                ...
# 6906  positive  @TomFelton Hope you win tonight Tom!  Your US ...
# 6907  positive  RT @AlexO_3 Monday Night Football be the move ...
# 6908   neutral  Colts owner Jim Irsay will give $64,753 to vic...
# 6909  positive  If I'm reading the Twitter Trend list correctl...
# 6910  positive                           Colts game tonight! Yay!
# 6911   neutral  Is this on tv again? "@kugrlover: Most of Reds...
# 6912  positive  What will have a better TV rating...#Cardinals...
# 6913  positive  Yes. I'm ready for HS, college & pro. Bring it...
# 6914  positive  Trying to leave, I'm only 10 minutes late (so ...
# 6915  negative  I fail to see why the Rams are playing TWICE o...
# 6916  negative  @Hopesolofans1 @hopesolo I hope my iPhone gets...
# 6917   neutral           On the night Hank Williams came to town.
# 6918  positive  RT @SmileLikeMiley: There won't be just a Part...
# 6919  positive  Man was that Jets and Cowboys game awesome or ...
# 6920  positive                   MNF tonight! Let's go Sexy Rexy!
# 6921  negative  Lmao RT @HeatherNoel13: Curtis painter looks l...
# 6922   neutral  Monday Night Football #TeamTexans all day & to...
# 6923   neutral  @PierreGarcon85 come out and watch THOSE GUYS ...
# 6924  negative  Hank Williams & whisky in an empty bar on a Fr...
# 6925  positive  @kristiyamaguchi @markballas love that you 2 k...
# 6926  positive  Huge thanks to those of you who came out to my...
# 6927  negative  RT @Rach_RVX: #Londonriots is trending 3rd wor...
# 6928  positive  Monday Night Football - Gary Neville did well ...
# 6929  positive  @andrewsikora The Tigers know it's a big game ...
# 6930  positive  New cast of DWTS tba at 8pm tonight!! So excit...
# 6931  negative  @stoney16 @JeffMossDSR I'd recommend just turn...
# 6932  positive  RT @MNFootNg It's monday and Monday Night Foot...
# 6933  positive  All I know is the road for that Lomardi start ...
# 6934   neutral  All Blue and White fam, we r meeting at Golden...
# 6935  positive  @DariusButler28   Have a great game agaist Tam...
#
# [6936 rows x 2 columns]
# -----Data-------

# %%
def labelencode(df):
    data=df['types']
    values=np.array(data)
    label=LabelEncoder()
    intencode=label.fit_transform(values)
    df['typeint']=intencode
    print(list(label.inverse_transform([0,1,2])))
    #df['typeint'].plot(kind='hist')
    #k=np.arange(0,16)
    #x=label.inverse_transform(k)   #can access encoded actual value using x
    #print(values)
    return df

df=labelencode(df)
#print(df)
shortdata=df.iloc[:,1]
#print(shortdata)
# Out:
# ['negative', 'neutral', 'positive']

# %%
#removing stopwords 
from nltk.corpus import stopwords
stop=stopwords.words("english")
print('------Removing stopwords------')
shortdata=shortdata.apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
#shortdata=shortdata.apply(lambda x: ' '.join([word for word in x.split() if word!='i' or word!='I']))
print(shortdata)
#stemming of words
ps = PorterStemmer()
print('-------Stemming--------')
shortdata = shortdata.apply(lambda x: ' '.join([ps.stem(word) for word in x.split() ]))
print(shortdata)
# Out:
# ------Removing stopwords------
# 0       Iranian general says Israel's Iron Dome can't ...
# 1       J Davlar 11th. Main rivals team Poland. Hopefu...
# 2       Talking ACT's &amp;&amp; SAT's, deciding I wan...
# 3       They may SuperBowl Dallas, Dallas ain't winnin...
# 4       Im bringing monster load candy tomorrow, I hop...
# 5       Apple software, retail chiefs overhaul: SAN FR...
# 6       @oluoch @victor_otti @kunjand I watched it! Sr...
# 7       #Livewire Nadal confirmed Mexican Open Februar...
# 8       @MsSheLahY I didnt want pop up... yep chapel h...
# 9       @Alyoup005 @addicted2haley hmmmm November odd ...
# 10      #Iran US delisting MKO global terrorists list ...
# 11      Good Morning Becky ! Thursday going Fantastic ...
# 12      Expect light-moderate rains E. Visayas; Cebu, ...
# 13      One ticket left @49ers game tomorrow! Don't mi...
# 14      AFC away fans Saturday. All stuff 'she said no...
# 15      Game 1 NLCS rematch NFC Championship game tomo...
# 16      Never start working dreams goals tomorrow........
# 17      @TheFFAddict I Vick Flacco, needed upgrade. Vi...
# 18      Looks like Andy Android may little much fun ye...
# 19      @APGPhoto oooh nice .. Tis tempting go lakes N...
# 20      BLACK FRIDAY Huge Saving Aerial View City, Par...
# 21      @MelmurMel @PBandJenelley_1 @vl_delp_ham_ Jene...
# 22      Mohamed Morsi, Egypt's Muslim Brotherhood pres...
# 23      C'mon Avila! You got tagged guy looks like kid...
# 24      At first Grammy Awards, held 4 May 1959, Domen...
# 25      @JennetteMcHevan I studied day tomorrow I'm go...
# 26      Good morning Thursday. "Life fragile. We're gu...
# 27      #Twitition Mcfly come back Argentina time want...
# 28      #Broncos Peyton Manning named AFC Offensive Pl...
# 29      @TooZany bringing Kendrick Lamar 6th December!...
#                               ...
# 6906    @TomFelton Hope win tonight Tom! Your US world...
# 6907          RT @AlexO_3 Monday Night Football move too!
# 6908    Colts owner Jim Irsay give $64,753 victims fun...
# 6909    If I'm reading Twitter Trend list correctly, p...
# 6910                             Colts game tonight! Yay!
# 6911    Is tv again? "@kugrlover: Most Redskins starte...
# 6912    What better TV rating...#Cardinals v #Rockies ...
# 6913    Yes. I'm ready HS, college & pro. Bring it! @b...
# 6914    Trying leave, I'm 10 minutes late (so far) - s...
# 6915    I fail see Rams playing TWICE MNF Fall-isn't e...
# 6916    @Hopesolofans1 @hopesolo I hope iPhone gets se...
# 6917                    On night Hank Williams came town.
# 6918    RT @SmileLikeMiley: There Party USA tonight th...
# 6919    Man Jets Cowboys game awesome what. Great ente...
# 6920                     MNF tonight! Let's go Sexy Rexy!
# 6921    Lmao RT @HeatherNoel13: Curtis painter looks l...
# 6922    Monday Night Football #TeamTexans day & tomorr...
# 6923    @PierreGarcon85 come watch THOSE GUYS softball...
# 6924    Hank Williams & whisky empty bar Friday. Reall...
# 6925    @kristiyamaguchi @markballas love 2 keep touch...
# 6926    Huge thanks came photography workshops today T...
# 6927    RT @Rach_RVX: #Londonriots trending 3rd worldw...
# 6928    Monday Night Football - Gary Neville well even...
# 6929    @andrewsikora The Tigers know big game well: r...
# 6930    New cast DWTS tba 8pm tonight!! So excited :) ...
# 6931    @stoney16 @JeffMossDSR I'd recommend turning w...
# 6932    RT @MNFootNg It's monday Monday Night Football...
# 6933    All I know road Lomardi start TONIGHT!!!! We s...
# 6934    All Blue White fam, r meeting Golden Corral di...
# 6935    @DariusButler28 Have great game agaist Tampa B...
# Name: posts, Length: 6936, dtype: object
# -------Stemming--------
# 0       iranian gener say israel' iron dome can't deal...
# 1       J davlar 11th. main rival team poland. hope ma...
# 2       talk act' &amp;&amp; sat's, decid I want go co...
# 3       they may superbowl dallas, dalla ain't win sup...
# 4       Im bring monster load candi tomorrow, I hope g...
# 5       appl software, retail chief overhaul: san fran...
# 6       @oluoch @victor_otti @kunjand I watch it! srid...
# 7       #livewir nadal confirm mexican open february: ...
# 8       @msshelahi I didnt want pop up... yep chapel h...
# 9       @alyoup005 @addicted2haley hmmmm novemb odd re...
# 10      #iran US delist mko global terrorist list line...
# 11      good morn becki ! thursday go fantast ! @swede...
# 12      expect light-moder rain E. visayas; cebu, boho...
# 13      one ticket left @49er game tomorrow! don't mis...
# 14      afc away fan saturday. all stuff 'she said no'...
# 15      game 1 nlc rematch nfc championship game tomor...
# 16      never start work dream goal tomorrow......tomo...
# 17      @theffaddict I vick flacco, need upgrade. vick...
# 18      look like andi android may littl much fun yest...
# 19      @apgphoto oooh nice .. ti tempt go lake nikon ...
# 20      black friday huge save aerial view city, pari ...
# 21      @melmurmel @pbandjenelley_1 @vl_delp_ham_ jene...
# 22      moham morsi, egypt' muslim brotherhood preside...
# 23      c'mon avila! you got tag guy look like kid bil...
# 24      At first grammi awards, held 4 may 1959, domen...
# 25      @jennettemchevan I studi day tomorrow i'm go f...
# 26      good morn thursday. "life fragile. we'r guaran...
# 27      #twitit mcfli come back argentina time want co...
# 28      #bronco peyton man name afc offens player mont...
# 29      @toozani bring kendrick lamar 6th december!?! ...
#                               ...
# 6906    @tomfelton hope win tonight tom! your US world...
# 6907           RT @alexo_3 monday night footbal move too!
# 6908    colt owner jim irsay give $64,753 victim fund ...
# 6909    If i'm read twitter trend list correctly, peop...
# 6910                              colt game tonight! yay!
# 6911    Is tv again? "@kugrlover: most redskin starter...
# 6912    what better TV rating...#cardin v #rocki tonig...
# 6913    yes. i'm readi hs, colleg & pro. bring it! @bl...
# 6914    tri leave, i'm 10 minut late (so far) - still ...
# 6915    I fail see ram play twice mnf fall-isn't enoug...
# 6916    @hopesolofans1 @hopesolo I hope iphon get serv...
# 6917                     On night hank william came town.
# 6918    RT @smilelikemiley: there parti usa tonight th...
# 6919    man jet cowboy game awesom what. great enterta...
# 6920                      mnf tonight! let' go sexi rexy!
# 6921    lmao RT @heathernoel13: curti painter look lik...
# 6922    monday night footbal #teamtexan day & tomorrow...
# 6923    @pierregarcon85 come watch those guy softbal n...
# 6924    hank william & whiski empti bar friday. really...
# 6925    @kristiyamaguchi @markballa love 2 keep touch ...
# 6926    huge thank came photographi workshop today ter...
# 6927    RT @rach_rvx: #londonriot trend 3rd worldwid ....
# 6928    monday night footbal - gari nevil well even ti...
# 6929    @andrewsikora the tiger know big game well: re...
# 6930    new cast dwt tba 8pm tonight!! So excit :) the...
# 6931    @stoney16 @jeffmossdsr i'd recommend turn wait...
# 6932    RT @mnfootng it' monday monday night footbal m...
# 6933    all I know road lomardi start tonight!!!! We s...
# 6934    all blue white fam, r meet golden corral dinne...
# 6935    @dariusbutler28 have great game agaist tampa b...
# Name: posts, Length: 6936, dtype: object

# %%
#removing non-alphabets
shortdata=shortdata.apply(lambda x: ' '.join([word for word in x.split() if word.isalpha()]))

from nltk.stem.wordnet import WordNetLemmatizer
lmtzr = WordNetLemmatizer()
#print(shortdata)
print('-------Lemmatization--------')
shortdata = shortdata.apply(lambda x: ' '.join([lmtzr.lemmatize(word,'v') for word in x.split() ]))
print(shortdata)

print('--------Removing punctuations--------')
def clear_punctuation(s):
	import string
	#print("\n")
	clear_string = ""
	for symbol in s:
		if symbol not in string.punctuation:
			clear_string += symbol
	return clear_string

shortdata = shortdata.apply(lambda x: ''.join(clear_punctuation(x))  )
print(shortdata)
#for line in shortdata:
#	print(line)
#	print('\n')
# Out:
# -------Lemmatization--------
# 0       iranian gener say iron dome deal missil talk l...
# 1       J davlar main rival team hope make success end...
# 2       talk decid I want go appli colleg everyth coll...
# 3            they may superbowl dalla win not quarterback
# 4           Im bring monster load candi I hope get squich
# 5       appl retail chief san francisco appl inc ceo t...
# 6                           I watch U rememb sun morn nta
# 7        nadal confirm mexican open rafael nadal set play
# 8       I didnt want pop yep chapel hill next wednesda...
# 9       hmmmm novemb odd releas date true becom big en...
# 10      US delist mko global terrorist list line iran ...
# 11                    good morn becki thursday go fantast
# 12      expect rain samar leyt chanc rain expect fair ...
# 13      one ticket leave game miss rematch nfc champio...
# 14              afc away fan all stuff say when turn back
# 15      game nlc rematch nfc championship game gonna c...
# 16       never start work dream goal never mean anyth act
# 17          I vick need vick may get jen back I think win
# 18              look like andi android may littl much fun
# 19           oooh nice ti tempt go lake nikon hmmmm I may
# 20      black friday huge save aerial view pari la la ...
# 21                               jenel say alon say weird
# 22      moham muslim brotherhood instruct suprem counc...
# 23      you get tag guy look like kid bill murray rese...
# 24      At first grammi hold may domenico modugno beat...
# 25              I studi day tomorrow go omg jennett gonna
# 26      good morn guarante tomorrow give everyth tim cook
# 27       mcfli come back argentina time want come mar del
# 28       peyton man name afc offens player second tom tie
# 29                        bring kendrick lamar get ticket
#                               ...
# 6906          hope win tonight your US worldwid fan cheer
# 6907                         RT monday night footbal move
# 6908    colt owner jim irsay give victim fund state fa...
# 6909    If read twitter trend list peopl realli happi ...
# 6910                                            colt game
# 6911    Is tv most redskin starter sit tonight vs tamp...
# 6912    what better TV v tonight mnf reg season hardba...
# 6913    readi colleg bring make monday We come home yo...
# 6914    tri minut late still need dash ladi wait hear dwt
# 6915      I fail see ram play twice mnf div game isnt til
# 6916    I hope iphon get servic tonit find dwt caus I ...
# 6917                           On night hank william come
# 6918    RT there parti usa tonight parti worldwid mile...
# 6919    man jet cowboy game awesom great entertain tha...
# 6920                                          mnf go sexi
# 6921    lmao RT curti painter look like kind guy would...
# 6922                             monday night footbal day
# 6923    come watch those guy softbal next saturday aug...
# 6924    hank william whiski empti bar guy cute bartend...
# 6925    love keep touch one favorit dwt coupl reason I...
# 6926     huge thank come photographi workshop today terra
# 6927     RT trend worldwid thi not someth proud unit sort
# 6928    monday night footbal gari nevil well even time...
# 6929    the tiger know big game rest martinez alburque...
# 6930    new cast dwt tba So excit the meet tonight bet...
# 6931                          recommend turn wait verland
# 6932               RT monday monday night footbal RT love
# 6933    all I know road lomardi start We set record mn...
# 6934    all blue white r meet golden corral dinner ton...
# 6935                     have great game agaist tampa bay
# Name: posts, Length: 6936, dtype: object
# --------Removing punctuations--------
# 0       iranian gener say iron dome deal missil talk l...
# 1       J davlar main rival team hope make success end...
# 2       talk decid I want go appli colleg everyth coll...
# 3            they may superbowl dalla win not quarterback
# 4           Im bring monster load candi I hope get squich
# 5       appl retail chief san francisco appl inc ceo t...
# 6                           I watch U rememb sun morn nta
# 7        nadal confirm mexican open rafael nadal set play
# 8       I didnt want pop yep chapel hill next wednesda...
# 9       hmmmm novemb odd releas date true becom big en...
# 10      US delist mko global terrorist list line iran ...
# 11                    good morn becki thursday go fantast
# 12      expect rain samar leyt chanc rain expect fair ...
# 13      one ticket leave game miss rematch nfc champio...
# 14              afc away fan all stuff say when turn back
# 15      game nlc rematch nfc championship game gonna c...
# 16       never start work dream goal never mean anyth act
# 17          I vick need vick may get jen back I think win
# 18              look like andi android may littl much fun
# 19           oooh nice ti tempt go lake nikon hmmmm I may
# 20      black friday huge save aerial view pari la la ...
# 21                               jenel say alon say weird
# 22      moham muslim brotherhood instruct suprem counc...
# 23      you get tag guy look like kid bill murray rese...
# 24      At first grammi hold may domenico modugno beat...
# 25              I studi day tomorrow go omg jennett gonna
# 26      good morn guarante tomorrow give everyth tim cook
# 27       mcfli come back argentina time want come mar del
# 28       peyton man name afc offens player second tom tie
# 29                        bring kendrick lamar get ticket
#                               ...
# 6906          hope win tonight your US worldwid fan cheer
# 6907                         RT monday night footbal move
# 6908    colt owner jim irsay give victim fund state fa...
# 6909    If read twitter trend list peopl realli happi ...
# 6910                                            colt game
# 6911    Is tv most redskin starter sit tonight vs tamp...
# 6912    what better TV v tonight mnf reg season hardba...
# 6913    readi colleg bring make monday We come home yo...
# 6914    tri minut late still need dash ladi wait hear dwt
# 6915      I fail see ram play twice mnf div game isnt til
# 6916    I hope iphon get servic tonit find dwt caus I ...
# 6917                           On night hank william come
# 6918    RT there parti usa tonight parti worldwid mile...
# 6919    man jet cowboy game awesom great entertain tha...
# 6920                                          mnf go sexi
# 6921    lmao RT curti painter look like kind guy would...
# 6922                             monday night footbal day
# 6923    come watch those guy softbal next saturday aug...
# 6924    hank william whiski empti bar guy cute bartend...
# 6925    love keep touch one favorit dwt coupl reason I...
# 6926     huge thank come photographi workshop today terra
# 6927     RT trend worldwid thi not someth proud unit sort
# 6928    monday night footbal gari nevil well even time...
# 6929    the tiger know big game rest martinez alburque...
# 6930    new cast dwt tba So excit the meet tonight bet...
# 6931                          recommend turn wait verland
# 6932               RT monday monday night footbal RT love
# 6933    all I know road lomardi start We set record mn...
# 6934    all blue white r meet golden corral dinner ton...
# 6935                     have great game agaist tampa bay
# Name: posts, Length: 6936, dtype: object

# %%
def strip_all_entities(text):
	import string
	entity_prefixes = ['@']
	for separator in  string.punctuation:
		if separator not in entity_prefixes :
			text = text.replace(separator,' ')
	words = []
	for word in text.split():
		word = word.strip()
		if word:
			if word[0] not in entity_prefixes:
				words.append(word)
	return ' '.join(words)

shortdata = shortdata.apply(lambda x: ''.join(strip_all_entities(x))  )

# %%
i=0
arr=[]
print("-----PREPROCESSED_DATA------")
count=0
for line in shortdata:
    df.iloc[i,1]=line
    i=i+1
print(df)



'''for column in dataset.columns:
    if dataset[column].dtype == type(object):
        le = LabelEncoder()
        dataset[column] = le.fit_transform(dataset[column])'''
# Out:
# -----PREPROCESSED_DATA------
#          types                                              posts  typeint
# 0     negative  iranian gener say iron dome deal missil talk l...        0
# 1     positive  J davlar main rival team hope make success end...        2
# 2     negative  talk decid I want go appli colleg everyth coll...        0
# 3     negative       they may superbowl dalla win not quarterback        0
# 4      neutral      Im bring monster load candi I hope get squich        1
# 5      neutral  appl retail chief san francisco appl inc ceo t...        1
# 6     positive                      I watch U rememb sun morn nta        2
# 7      neutral   nadal confirm mexican open rafael nadal set play        1
# 8     positive  I didnt want pop yep chapel hill next wednesda...        2
# 9      neutral  hmmmm novemb odd releas date true becom big en...        1
# 10     neutral  US delist mko global terrorist list line iran ...        1
# 11    positive                good morn becki thursday go fantast        2
# 12     neutral  expect rain samar leyt chanc rain expect fair ...        1
# 13    positive  one ticket leave game miss rematch nfc champio...        2
# 14    negative          afc away fan all stuff say when turn back        0
# 15     neutral  game nlc rematch nfc championship game gonna c...        1
# 16    positive   never start work dream goal never mean anyth act        2
# 17    positive      I vick need vick may get jen back I think win        2
# 18    positive          look like andi android may littl much fun        2
# 19    positive       oooh nice ti tempt go lake nikon hmmmm I may        2
# 20     neutral  black friday huge save aerial view pari la la ...        1
# 21    negative                           jenel say alon say weird        0
# 22     neutral  moham muslim brotherhood instruct suprem counc...        1
# 23     neutral  you get tag guy look like kid bill murray rese...        1
# 24     neutral  At first grammi hold may domenico modugno beat...        1
# 25    positive          I studi day tomorrow go omg jennett gonna        2
# 26    positive  good morn guarante tomorrow give everyth tim cook        2
# 27    positive   mcfli come back argentina time want come mar del        2
# 28     neutral   peyton man name afc offens player second tom tie        1
# 29     neutral                    bring kendrick lamar get ticket        1
# ...        ...                                                ...      ...
# 6906  positive        hope win tonight your US worldwid fan cheer        2
# 6907  positive                       RT monday night footbal move        2
# 6908   neutral  colt owner jim irsay give victim fund state fa...        1
# 6909  positive  If read twitter trend list peopl realli happi ...        2
# 6910  positive                                          colt game        2
# 6911   neutral  Is tv most redskin starter sit tonight vs tamp...        1
# 6912  positive  what better TV v tonight mnf reg season hardba...        2
# 6913  positive  readi colleg bring make monday We come home yo...        2
# 6914  positive  tri minut late still need dash ladi wait hear dwt        2
# 6915  negative    I fail see ram play twice mnf div game isnt til        0
# 6916  negative  I hope iphon get servic tonit find dwt caus I ...        0
# 6917   neutral                         On night hank william come        1
# 6918  positive  RT there parti usa tonight parti worldwid mile...        2
# 6919  positive  man jet cowboy game awesom great entertain tha...        2
# 6920  positive                                        mnf go sexi        2
# 6921  negative  lmao RT curti painter look like kind guy would...        0
# 6922   neutral                           monday night footbal day        1
# 6923   neutral  come watch those guy softbal next saturday aug...        1
# 6924  negative  hank william whiski empti bar guy cute bartend...        0
# 6925  positive  love keep touch one favorit dwt coupl reason I...        2
# 6926  positive   huge thank come photographi workshop today terra        2
# 6927  negative   RT trend worldwid thi not someth proud unit sort        0
# 6928  positive  monday night footbal gari nevil well even time...        2
# 6929  positive  the tiger know big game rest martinez alburque...        2
# 6930  positive  new cast dwt tba So excit the meet tonight bet...        2
# 6931  negative                        recommend turn wait verland        0
# 6932  positive             RT monday monday night footbal RT love        2
# 6933  positive  all I know road lomardi start We set record mn...        2
# 6934   neutral  all blue white r meet golden corral dinner ton...        1
# 6935  positive                   have great game agaist tampa bay        2
#
# [6936 rows x 3 columns]
# 'for column in dataset.columns:\n    if dataset[column].dtype == type(object):\n        le = LabelEncoder()\n        dataset[column] = le.fit_transform(dataset[column])'

# %%
proc_data=np.array(df['posts'])
label=np.array(df['typeint'])
print(len(proc_data))
print(len(label))
# Out:
# 6936
# 6936

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(proc_data, label, test_size=0.2)

# %%
print(train_x)
# Out:
# ['@ashaLadawn yeah, Imma be in vegas from 18th-23rd so I just want a dinner in dallas with friends'
#  "Don't miss these upcoming SPC events:  On November 15th - A post-election breakdown with Mark and Mark,... http://t.co/F5I8aq9x"
#  'Petrolia art in the Park is tomorrow and Saturday!  We will be set up in front of Mercantile Co.  on Petrolia Line across from the park!'
#  ...
#  '2nd day of #VINOOMANKAD U19:(ODI): Haryana, Kerala, Andhra, TN, Mumbai, Baroda, UP won their matches against J&amp;K, KAR, Hyd,Goa, MH,Baroda,UP'
#  '@zooarchaeologis cool, come to Monday group, they would love it, we often do day trips out together, Fire Station, World Book Day and stuff!'
#  'Nick Diaz said he would "fight GSP tomorrow if the UFC asked". Except, you know, they wouldn\'t... because you\'re suspended...']

# %%
import json
import keras
import keras.preprocessing.text as kpt
from keras.preprocessing.text import Tokenizer

# only work with the 3000 most popular words found in our dataset
max_words = 3000

# create a new Tokenizer
tokenizer = Tokenizer(num_words=max_words)
# feed our tweets to the Tokenizer
tokenizer.fit_on_texts(train_x)

# Tokenizers come with a convenient list of words and IDs
dictionary = tokenizer.word_index
# Let's save this out so we can use it later
with open('dictionary.json', 'w') as dictionary_file:
    json.dump(dictionary, dictionary_file)


def convert_text_to_index_array(text):
    # one really important thing that `text_to_word_sequence` does
    # is make all texts the same length -- in this case, the length
    # of the longest text in the set.
    return [dictionary[word] for word in kpt.text_to_word_sequence(text)]

allWordIndices = []
# for each tweet, change each token to its ID in the Tokenizer's word_index
for text in train_x:
    wordIndices = convert_text_to_index_array(text)
    allWordIndices.append(wordIndices)

# now we have a list of all tweets converted to index arrays.
# cast as an array for future usage.
allWordIndices = np.asarray(allWordIndices)

# create one-hot matrices out of the indexed tweets
train_x = tokenizer.sequences_to_matrix(allWordIndices, mode='binary')
# treat the labels as categories

# %%
train_y = keras.utils.to_categorical(train_y, 3)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation

model = Sequential()
model.add(Dense(500, input_shape=(max_words,), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))
sgd=keras.optimizers.SGD(lr=0.001, momentum=0.0, decay=0.0, nesterov=False)
model.compile(loss='categorical_crossentropy',
  optimizer=sgd,
  metrics=['accuracy'])

# %%
model.fit(train_x, train_y,
  batch_size=32,
  epochs=5,
  verbose=1,
  validation_split=0.1,
  shuffle=True)
# Out:
# Train on 4993 samples, validate on 555 samples
# Epoch 1/5
# 4993/4993 [==============================] - 2s 386us/step - loss: 1.1042 - acc: 0.3437 - val_loss: 1.0832 - val_acc: 0.4414
# Epoch 2/5
# 4993/4993 [==============================] - 2s 335us/step - loss: 1.0772 - acc: 0.4356 - val_loss: 1.0600 - val_acc: 0.4829
# Epoch 3/5
# 4993/4993 [==============================] - 2s 337us/step - loss: 1.0576 - acc: 0.4685 - val_loss: 1.0419 - val_acc: 0.4973
# Epoch 4/5
# 4993/4993 [==============================] - 2s 352us/step - loss: 1.0388 - acc: 0.4781 - val_loss: 1.0281 - val_acc: 0.4955
# Epoch 5/5
# 4993/4993 [==============================] - 2s 343us/step - loss: 1.0263 - acc: 0.4829 - val_loss: 1.0173 - val_acc: 0.4973

# %%
model_json = model.to_json()
with open('model.json', 'w') as json_file:
    json_file.write(model_json)

model.save_weights('model.h5')

# %%
import json
import numpy as np
import keras
import keras.preprocessing.text as kpt
from keras.preprocessing.text import Tokenizer
from keras.models import model_from_json

# we're still going to use a Tokenizer here, but we don't need to fit it
tokenizer = Tokenizer(num_words=3000)
# for human-friendly printing
labels = ['negative','neutral','positive']

# read in our saved dictionary
with open('dictionary.json', 'r') as dictionary_file:
    dictionary = json.load(dictionary_file)

# this utility makes sure that all the words in your input
# are registered in the dictionary
# before trying to turn them into a matrix.
def convert_text_to_index_array(text):
    words = kpt.text_to_word_sequence(text)
    wordIndices = []
    for word in words:
        if word in dictionary:
            wordIndices.append(dictionary[word])
        else:
            print("'%s' not in training corpus; ignoring." %(word))
    return wordIndices

# read in your saved model structure
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
# and create a model from that
model = model_from_json(loaded_model_json)
# and weight your nodes with your saved values
model.load_weights('model.h5')

# okay here's the interactive part

# %%
eval="hello how are you?"
testArr = convert_text_to_index_array(eval)
inp = tokenizer.sequences_to_matrix([testArr], mode='binary')
# predict which bucket your input belongs in
pred = model.predict(inp)
# and print it for the humons
print("%s sentiment; %f%% confidence" % (labels[np.argmax(pred)], pred[0][np.argmax(pred)] * 100))
# Out:
# 'are' not in training corpus; ignoring.
# neutral sentiment; 50.696129% confidence

# %%
print(test_x)
# Out:
# ['We nail trifecta today check'
#  'anonym just realiz watchin youtub account upload video'
#  'morn despertado peusto la mtv estaban hablando de green que bonito' ...
#  'ok remind convo march brook beat devon alexand world and khan still glass chin'
#  'istrategi playstat network mainten monday If look play psn game upcom'
#  'our beauti new firepit time friday night journey mysteri']

# %%
que=[]
for i in test_x:
    #evalSentence = input('Input a sentence to be evaluated, or Enter to quit: ')
    evalSentence=i
    if len(evalSentence) == 0:
        break

    # format your input for the neural net
    testArr = convert_text_to_index_array(evalSentence)
    inp = tokenizer.sequences_to_matrix([testArr], mode='binary')
    # predict which bucket your input belongs in
    pred = model.predict(inp)
    k=np.amax(pred[0])
    print(pred[0])
    print(k)
    ind=list(pred[0]).index(k)
    print(labels[ind])
    que.append(ind)
    # and print it for the humons
    #print("%s sentiment; %f%% confidence" % (labels[np.argmax(pred)], pred[0][np.argmax(pred)] * 100))
# Out:
# [0.10618798 0.5148507  0.37896135]
# 0.5148507
# neutral
# [0.06706583 0.6408729  0.29206127]
# 0.6408729
# neutral
# 'despertado' not in training corpus; ignoring.
# 'peusto' not in training corpus; ignoring.
# 'estaban' not in training corpus; ignoring.
# 'hablando' not in training corpus; ignoring.
# 'bonito' not in training corpus; ignoring.
# [0.12712313 0.4514551  0.42142174]
# 0.4514551
# neutral
# [0.11605512 0.70962274 0.17432211]
# 0.70962274
# neutral
# 'manciti' not in training corpus; ignoring.
# 'aguero' not in training corpus; ignoring.
# 'dzeko' not in training corpus; ignoring.
# 'thrash' not in training corpus; ignoring.
# [0.12562141 0.37201265 0.5023659 ]
# 0.5023659
# positive
# 'maccyd' not in training corpus; ignoring.
# [0.20966356 0.48931563 0.30102083]
# 0.48931563
# neutral
# [0.08476992 0.2957495  0.6194806 ]
# 0.6194806
# positive
# 'welch' not in training corpus; ignoring.
# [0.1599729  0.54692644 0.29310063]
# 0.54692644
# neutral
# 'premiership' not in training corpus; ignoring.
# [0.15779483 0.5875224  0.2546827 ]
# 0.5875224
# neutral
# [0.07723103 0.47004277 0.45272622]
# 0.47004277
# neutral
# [0.23465893 0.3383995  0.42694154]
# 0.42694154
# positive
# 'cornwal' not in training corpus; ignoring.
# 'padstow' not in training corpus; ignoring.
# 'chip' not in training corpus; ignoring.
# [0.22741957 0.47164765 0.30093285]
# 0.47164765
# neutral
# 'masterclass' not in training corpus; ignoring.
# 'decad' not in training corpus; ignoring.
# 'tort' not in training corpus; ignoring.
# [0.06341181 0.10656188 0.8300263 ]
# 0.8300263
# positive
# [0.16270493 0.27066022 0.56663483]
# 0.56663483
# positive
# [0.13884225 0.7422396  0.11891815]
# 0.7422396
# neutral
# 'penderg' not in training corpus; ignoring.
# [0.26586872 0.33109924 0.403032  ]
# 0.403032
# positive
# 'jharkhand' not in training corpus; ignoring.
# 'tribal' not in training corpus; ignoring.
# [0.06474031 0.8229374  0.11232222]
# 0.8229374
# neutral
# [0.2849374  0.47076777 0.24429485]
# 0.47076777
# neutral
# [0.16562991 0.12270486 0.7116652 ]
# 0.7116652
# positive
# 'pist' not in training corpus; ignoring.
# [0.2422014  0.5672804  0.19051817]
# 0.5672804
# neutral
# [0.11674744 0.6210075  0.26224497]
# 0.6210075
# neutral
# 'asst' not in training corpus; ignoring.
# 'aight' not in training corpus; ignoring.
# [0.13038206 0.58525586 0.28436208]
# 0.58525586
# neutral
# 'bake' not in training corpus; ignoring.
# [0.11717498 0.5733693  0.30945572]
# 0.5733693
# neutral
# 'nye' not in training corpus; ignoring.
# [0.09074542 0.54425365 0.36500093]
# 0.54425365
# neutral
# [0.19274426 0.48735672 0.319899  ]
# 0.48735672
# neutral
# 'corrier' not in training corpus; ignoring.
# [0.06672558 0.8310756  0.10219879]
# 0.8310756
# neutral
# 'candyman' not in training corpus; ignoring.
# 'liquor' not in training corpus; ignoring.
# 'laffin' not in training corpus; ignoring.
# [0.28000605 0.23175868 0.48823524]
# 0.48823524
# positive
# [0.09287845 0.6864401  0.22068143]
# 0.6864401
# neutral
# 'gulf' not in training corpus; ignoring.
# [0.22109279 0.55683917 0.2220681 ]
# 0.55683917
# neutral
# 'kate' not in training corpus; ignoring.
# [0.11875042 0.57940084 0.3018487 ]
# 0.57940084
# neutral
# [0.11241797 0.42391905 0.46366292]
# 0.46366292
# positive
# 'zara' not in training corpus; ignoring.
# [0.29069883 0.5526129  0.15668824]
# 0.5526129
# neutral
# [0.18819179 0.31750005 0.49430808]
# 0.49430808
# positive
# [0.04601569 0.08127359 0.8727107 ]
# 0.8727107
# positive
# 'shoulder' not in training corpus; ignoring.
# [0.19138242 0.43861002 0.37000757]
# 0.43861002
# neutral
# [0.01909966 0.01498339 0.96591693]
# 0.96591693
# positive
# [0.10893585 0.6767998  0.21426433]
# 0.6767998
# neutral
# [0.09438507 0.4887544  0.41686055]
# 0.4887544
# neutral
# 'sportiv' not in training corpus; ignoring.
# [0.06084402 0.12221908 0.8169369 ]
# 0.8169369
# positive
# 'literatur' not in training corpus; ignoring.
# [0.04095649 0.24752906 0.7115144 ]
# 0.7115144
# positive
# [0.18310145 0.12731001 0.68958855]
# 0.68958855
# positive
# 'kniteforc' not in training corpus; ignoring.
# 'boxset' not in training corpus; ignoring.
# [0.10285702 0.34649768 0.5506453 ]
# 0.5506453
# positive
# 'sah' not in training corpus; ignoring.
# [0.10371926 0.32448593 0.5717948 ]
# 0.5717948
# positive
# [0.11989238 0.63335407 0.24675356]
# 0.63335407
# neutral
# 'gizmo' not in training corpus; ignoring.
# [0.03798359 0.1261184  0.83589804]
# 0.83589804
# positive
# [0.20584059 0.37521842 0.418941  ]
# 0.418941
# positive
# [0.16316456 0.37478623 0.46204916]
# 0.46204916
# positive
# 'strategi' not in training corpus; ignoring.
# 'agricultur' not in training corpus; ignoring.
# [0.1185561  0.44948792 0.431956  ]
# 0.44948792
# neutral
# [0.02634806 0.11632583 0.85732603]
# 0.85732603
# positive
# 'dematha' not in training corpus; ignoring.
# 'stag' not in training corpus; ignoring.
# 'regroup' not in training corpus; ignoring.
# 'wcac' not in training corpus; ignoring.
# [0.15651353 0.52118325 0.3223033 ]
# 0.52118325
# neutral
# [0.06627807 0.75919205 0.17452991]
# 0.75919205
# neutral
# 'delmar' not in training corpus; ignoring.
# 'boci' not in training corpus; ignoring.
# [0.049071   0.88359344 0.06733562]
# 0.88359344
# neutral
# 'mccormick' not in training corpus; ignoring.
# 'hyatt' not in training corpus; ignoring.
# [0.17046012 0.48673296 0.3428069 ]
# 0.48673296
# neutral
# [0.05016622 0.59686345 0.3529703 ]
# 0.59686345
# neutral
# [0.15582038 0.47182548 0.3723541 ]
# 0.47182548
# neutral
# [0.18831897 0.45702586 0.3546552 ]
# 0.45702586
# neutral
# [0.0161688  0.03981638 0.9440148 ]
# 0.9440148
# positive
# 'onstag' not in training corpus; ignoring.
# [0.06900826 0.6341069  0.29688486]
# 0.6341069
# neutral
# 'starcatch' not in training corpus; ignoring.
# [0.10308986 0.4199692  0.4769409 ]
# 0.4769409
# positive
# 'xp' not in training corpus; ignoring.
# [0.07903607 0.66499627 0.25596765]
# 0.66499627
# neutral
# 'boudin' not in training corpus; ignoring.
# [0.1343497  0.5138846  0.35176566]
# 0.5138846
# neutral
# 'swert' not in training corpus; ignoring.
# [0.32108998 0.40303102 0.27587897]
# 0.40303102
# neutral
# 'damien' not in training corpus; ignoring.
# 'hirst' not in training corpus; ignoring.
# 'aesthet' not in training corpus; ignoring.
# [0.12950833 0.7302244  0.14026731]
# 0.7302244
# neutral
# 'winchest' not in training corpus; ignoring.
# [0.16236594 0.5511602  0.28647384]
# 0.5511602
# neutral
# [0.1040791  0.42511472 0.47080618]
# 0.47080618
# positive
# [0.32176876 0.43207905 0.24615224]
# 0.43207905
# neutral
# 'investor' not in training corpus; ignoring.
# 'cellphon' not in training corpus; ignoring.
# [0.19547005 0.6063551  0.19817486]
# 0.6063551
# neutral
# 'dermot' not in training corpus; ignoring.
# [0.2819745  0.27208048 0.44594505]
# 0.44594505
# positive
# [0.26373774 0.25023413 0.4860281 ]
# 0.4860281
# positive
# [0.08575262 0.52576727 0.38848007]
# 0.52576727
# neutral
# [0.4184962  0.17620355 0.40530026]
# 0.4184962
# negative
# 'motor' not in training corpus; ignoring.
# 'vehicl' not in training corpus; ignoring.
# [0.1543928  0.70619166 0.13941556]
# 0.70619166
# neutral
# 'sbi' not in training corpus; ignoring.
# [0.05490427 0.7803293  0.16476637]
# 0.7803293
# neutral
# 'aft' not in training corpus; ignoring.
# [0.13790536 0.10511453 0.75698006]
# 0.75698006
# positive
# 'spotter' not in training corpus; ignoring.
# [0.3040869  0.3163205  0.37959254]
# 0.37959254
# positive
# [0.13614137 0.44110173 0.42275685]
# 0.44110173
# neutral
# [0.09421172 0.6775097  0.22827856]
# 0.6775097
# neutral
# [0.13541621 0.45253485 0.41204897]
# 0.45253485
# neutral
# 'playwright' not in training corpus; ignoring.
# 'mel' not in training corpus; ignoring.
# [0.18896666 0.31537336 0.49565998]
# 0.49565998
# positive
# [0.17619139 0.13290834 0.6909002 ]
# 0.6909002
# positive
# 'rayysss' not in training corpus; ignoring.
# [0.16337416 0.577471   0.2591548 ]
# 0.577471
# neutral
# [0.17585874 0.23720138 0.58693993]
# 0.58693993
# positive
# 'strattonfaxon' not in training corpus; ignoring.
# [0.11490483 0.717665   0.16743015]
# 0.717665
# neutral
# [0.14818737 0.51833093 0.3334817 ]
# 0.51833093
# neutral
# [0.08533635 0.6901837  0.22447994]
# 0.6901837
# neutral
# [0.07710568 0.7489687  0.1739256 ]
# 0.7489687
# neutral
# 'tick' not in training corpus; ignoring.
# [0.03554546 0.07262143 0.8918331 ]
# 0.8918331
# positive
# [0.15372725 0.58613634 0.26013643]
# 0.58613634
# neutral
# [0.27182245 0.32536745 0.40281007]
# 0.40281007
# positive
# 'pmln' not in training corpus; ignoring.
# [0.07879683 0.5532098  0.36799335]
# 0.5532098
# neutral
# [0.13649443 0.39556023 0.4679454 ]
# 0.4679454
# positive
# 'bazura' not in training corpus; ignoring.
# 'glenn' not in training corpus; ignoring.
# 'moustach' not in training corpus; ignoring.
# [0.2322162  0.33961222 0.4281716 ]
# 0.4281716
# positive
# [0.1506768 0.6108969 0.2384263]
# 0.6108969
# neutral
# [0.08983405 0.7494883  0.16067761]
# 0.7494883
# neutral
# 'estel' not in training corpus; ignoring.
# [0.07353601 0.6570427  0.26942134]
# 0.6570427
# neutral
# [0.05898211 0.81970745 0.12131047]
# 0.81970745
# neutral
# [0.0793259  0.6361598  0.28451434]
# 0.6361598
# neutral
# 'sweetest' not in training corpus; ignoring.
# [0.08865788 0.4341007  0.47724143]
# 0.47724143
# positive
# 'heck' not in training corpus; ignoring.
# [0.15079284 0.63528854 0.21391857]
# 0.63528854
# neutral
# [0.17906772 0.46548998 0.3554423 ]
# 0.46548998
# neutral
# [0.26042667 0.3561888  0.3833846 ]
# 0.3833846
# positive
# [0.07233991 0.07614259 0.8515175 ]
# 0.8515175
# positive
# 'pamper' not in training corpus; ignoring.
# [0.2444101 0.3090001 0.4465898]
# 0.4465898
# positive
# [0.20796245 0.5132487  0.27878895]
# 0.5132487
# neutral
# 'nicknam' not in training corpus; ignoring.
# [0.13404828 0.4634964  0.4024554 ]
# 0.4634964
# neutral
# 'ruthi' not in training corpus; ignoring.
# 'henshal' not in training corpus; ignoring.
# [0.09564734 0.71267444 0.19167818]
# 0.71267444
# neutral
# [0.13398352 0.585098   0.2809184 ]
# 0.585098
# neutral
# [0.22519496 0.44144174 0.33336332]
# 0.44144174
# neutral
# [0.35747653 0.20442894 0.4380945 ]
# 0.4380945
# positive
# 'homework' not in training corpus; ignoring.
# [0.12156522 0.20763007 0.6708047 ]
# 0.6708047
# positive
# [0.15414831 0.58668196 0.2591697 ]
# 0.58668196
# neutral
# [0.09468619 0.7745689  0.13074479]
# 0.7745689
# neutral
# [0.12134294 0.7333164  0.14534067]
# 0.7333164
# neutral
# [0.08636126 0.707785   0.20585372]
# 0.707785
# neutral
# 'hipster' not in training corpus; ignoring.
# [0.2088354  0.40994552 0.38121903]
# 0.40994552
# neutral
# 'happz' not in training corpus; ignoring.
# 'below' not in training corpus; ignoring.
# [0.10831647 0.67956555 0.21211794]
# 0.67956555
# neutral
# [0.41304183 0.32040143 0.26655674]
# 0.41304183
# negative
# 'bia' not in training corpus; ignoring.
# [0.13122317 0.45532653 0.41345027]
# 0.45532653
# neutral
# [0.11764109 0.45944253 0.4229164 ]
# 0.45944253
# neutral
# [0.2612171  0.5321519  0.20663106]
# 0.5321519
# neutral
# 'scriptwrit' not in training corpus; ignoring.
# 'shazia' not in training corpus; ignoring.
# 'permiss' not in training corpus; ignoring.
# [0.12905376 0.3011588  0.5697874 ]
# 0.5697874
# positive
# [0.08218645 0.43858072 0.47923282]
# 0.47923282
# positive
# [0.07680096 0.21227922 0.71091986]
# 0.71091986
# positive
# 'bolt' not in training corpus; ignoring.
# [0.24975686 0.4732978  0.27694532]
# 0.4732978
# neutral
# 'thuu' not in training corpus; ignoring.
# 'ainsworth' not in training corpus; ignoring.
# 'comin' not in training corpus; ignoring.
# [0.09062447 0.6990174  0.21035816]
# 0.6990174
# neutral
# [0.05051525 0.07837998 0.8711047 ]
# 0.8711047
# positive
# 'ddb' not in training corpus; ignoring.
# [0.07877598 0.7531868  0.16803722]
# 0.7531868
# neutral
# [0.17576437 0.49578547 0.32845017]
# 0.49578547
# neutral
# 'creator' not in training corpus; ignoring.
# 'ignit' not in training corpus; ignoring.
# 'fireston' not in training corpus; ignoring.
# 'surrend' not in training corpus; ignoring.
# [0.1363241  0.40813133 0.45554462]
# 0.45554462
# positive
# [0.02608498 0.06308662 0.91082835]
# 0.91082835
# positive
# [0.07042422 0.2855962  0.64397955]
# 0.64397955
# positive
# [0.1569512  0.60810685 0.23494188]
# 0.60810685
# neutral
# 'cathedr' not in training corpus; ignoring.
# [0.11442512 0.65660065 0.22897418]
# 0.65660065
# neutral
# [0.09024984 0.4304264  0.47932371]
# 0.47932371
# positive
# 'pave' not in training corpus; ignoring.
# [0.26555791 0.5166557  0.21778639]
# 0.5166557
# neutral
# [0.0772558 0.2787429 0.6440013]
# 0.6440013
# positive
# [0.08984236 0.73000485 0.18015277]
# 0.73000485
# neutral
# 'dunde' not in training corpus; ignoring.
# [0.20480038 0.12512946 0.6700701 ]
# 0.6700701
# positive
# [0.09005091 0.65752864 0.25242049]
# 0.65752864
# neutral
# 'effat' not in training corpus; ignoring.
# [0.11910737 0.36786392 0.51302874]
# 0.51302874
# positive
# 'portland' not in training corpus; ignoring.
# 'knit' not in training corpus; ignoring.
# [0.06283531 0.23670068 0.700464  ]
# 0.700464
# positive
# 'mamata' not in training corpus; ignoring.
# 'oppos' not in training corpus; ignoring.
# 'cylind' not in training corpus; ignoring.
# [0.06638093 0.84673434 0.08688471]
# 0.84673434
# neutral
# [0.14377327 0.52880377 0.3274229 ]
# 0.52880377
# neutral
# [0.0795703  0.7106077  0.20982207]
# 0.7106077
# neutral
# [0.06240623 0.4368444  0.50074935]
# 0.50074935
# positive
# [0.10168036 0.4235707  0.474749  ]
# 0.474749
# positive
# [0.12889095 0.25150186 0.6196072 ]
# 0.6196072
# positive
# 'marku' not in training corpus; ignoring.
# 'schulz' not in training corpus; ignoring.
# [0.02732541 0.7007204  0.27195415]
# 0.7007204
# neutral
# 'charlestown' not in training corpus; ignoring.
# [0.1450517  0.57077426 0.28417403]
# 0.57077426
# neutral
# [0.14487323 0.4228087  0.43231806]
# 0.43231806
# positive
# [0.13113345 0.53898185 0.3298847 ]
# 0.53898185
# neutral
# [0.09334553 0.6139947  0.2926598 ]
# 0.6139947
# neutral
# [0.09918188 0.69386727 0.20695084]
# 0.69386727
# neutral
# 'niro' not in training corpus; ignoring.
# [0.01965956 0.02341483 0.95692563]
# 0.95692563
# positive
# [0.18360986 0.27349788 0.54289234]
# 0.54289234
# positive
# 'anastasia' not in training corpus; ignoring.
# [0.13695328 0.45318907 0.40985754]
# 0.45318907
# neutral
# [0.09577134 0.7100658  0.1941628 ]
# 0.7100658
# neutral
# [0.08842441 0.26104698 0.6505286 ]
# 0.6505286
# positive
# 'perugia' not in training corpus; ignoring.
# [0.09371143 0.67661154 0.22967707]
# 0.67661154
# neutral
# 'senran' not in training corpus; ignoring.
# 'kagura' not in training corpus; ignoring.
# [0.19187282 0.58156675 0.22656049]
# 0.58156675
# neutral
# [0.11153302 0.6909172  0.19754982]
# 0.6909172
# neutral
# 'mohsin' not in training corpus; ignoring.
# 'novel' not in training corpus; ignoring.
# 'typefac' not in training corpus; ignoring.
# [0.1526946  0.6525594  0.19474599]
# 0.6525594
# neutral
# [0.05331684 0.6872042  0.25947905]
# 0.6872042
# neutral
# [0.10046292 0.6187916  0.28074548]
# 0.6187916
# neutral
# [0.10641159 0.52604467 0.3675437 ]
# 0.52604467
# neutral
# 'favor' not in training corpus; ignoring.
# 'kanter' not in training corpus; ignoring.
# [0.23860185 0.5967951  0.16460305]
# 0.5967951
# neutral
# 'eo' not in training corpus; ignoring.
# [0.03729857 0.10784655 0.8548549 ]
# 0.8548549
# positive
# [0.07570376 0.5958212  0.32847515]
# 0.5958212
# neutral
# 'lawn' not in training corpus; ignoring.
# [0.2360205  0.29430518 0.46967432]
# 0.46967432
# positive
# [0.03200535 0.03041667 0.937578  ]
# 0.937578
# positive
# 'affection' not in training corpus; ignoring.
# [0.11213681 0.6891593  0.19870391]
# 0.6891593
# neutral
# 'iman' not in training corpus; ignoring.
# 'shumpert' not in training corpus; ignoring.
# 'karl' not in training corpus; ignoring.
# [0.10284332 0.37790236 0.51925427]
# 0.51925427
# positive
# [0.17764397 0.53169656 0.29065943]
# 0.53169656
# neutral
# 'borussia' not in training corpus; ignoring.
# [0.11966217 0.47702432 0.4033136 ]
# 0.47702432
# neutral
# [0.19778536 0.4256069  0.3766078 ]
# 0.4256069
# neutral
# 'vimeo' not in training corpus; ignoring.
# [0.06914955 0.71837425 0.21247618]
# 0.71837425
# neutral
# 'fx' not in training corpus; ignoring.
# 'sumthin' not in training corpus; ignoring.
# [0.09901436 0.14821546 0.7527702 ]
# 0.7527702
# positive
# 'takeaway' not in training corpus; ignoring.
# 'owe' not in training corpus; ignoring.
# [0.17934449 0.2628134  0.55784214]
# 0.55784214
# positive
# [0.1307387  0.37416387 0.49509743]
# 0.49509743
# positive
# [0.13952854 0.660802   0.19966948]
# 0.660802
# neutral
# [0.21779181 0.50081867 0.28138947]
# 0.50081867
# neutral
# 'mav' not in training corpus; ignoring.
# [0.14355911 0.45055544 0.4058854 ]
# 0.45055544
# neutral
# 'leprechaun' not in training corpus; ignoring.
# [0.15798144 0.5456946  0.29632396]
# 0.5456946
# neutral
# [0.12262879 0.706284   0.17108716]
# 0.706284
# neutral
# 'walcott' not in training corpus; ignoring.
# 'seventh' not in training corpus; ignoring.
# [0.08415147 0.41979977 0.4960487 ]
# 0.4960487
# positive
# 'sunset' not in training corpus; ignoring.
# [0.08037084 0.15613863 0.76349056]
# 0.76349056
# positive
# [0.07546374 0.18721826 0.737318  ]
# 0.737318
# positive
# [0.21051002 0.24089578 0.5485942 ]
# 0.5485942
# positive
# [0.20914221 0.2692439  0.5216139 ]
# 0.5216139
# positive
# [0.12360396 0.58590055 0.29049549]
# 0.58590055
# neutral
# [0.4225765  0.23606397 0.3413595 ]
# 0.4225765
# negative
# 'monitor' not in training corpus; ignoring.
# 'command' not in training corpus; ignoring.
# 'islam' not in training corpus; ignoring.
# [0.14064518 0.57064885 0.28870592]
# 0.57064885
# neutral
# [0.15476327 0.10081536 0.74442136]
# 0.74442136
# positive
# [0.17317097 0.6328353  0.1939937 ]
# 0.6328353
# neutral
# 'roller' not in training corpus; ignoring.
# [0.07845913 0.6002862  0.3212547 ]
# 0.6002862
# neutral
# 'virgin' not in training corpus; ignoring.
# [0.02139984 0.02093521 0.95766497]
# 0.95766497
# positive
# [0.06903016 0.7560945  0.17487529]
# 0.7560945
# neutral
# 'plein' not in training corpus; ignoring.
# 'visionnag' not in training corpus; ignoring.
# [0.08016772 0.7555202  0.16431212]
# 0.7555202
# neutral
# 'iam' not in training corpus; ignoring.
# [0.1499698 0.309926  0.5401042]
# 0.5401042
# positive
# 'approach' not in training corpus; ignoring.
# [0.06566031 0.821347   0.11299274]
# 0.821347
# neutral
# 'gabriel' not in training corpus; ignoring.
# 'irieapril' not in training corpus; ignoring.
# [0.03632476 0.08256923 0.881106  ]
# 0.881106
# positive
# 'francesco' not in training corpus; ignoring.
# 'totti' not in training corpus; ignoring.
# [0.1565959  0.67858046 0.16482364]
# 0.67858046
# neutral
# [0.08700349 0.14128095 0.7717155 ]
# 0.7717155
# positive
# [0.12330052 0.63491195 0.24178748]
# 0.63491195
# neutral
# [0.29222444 0.2857747  0.42200086]
# 0.42200086
# positive
# [0.14252374 0.1344558  0.7230205 ]
# 0.7230205
# positive
# [0.05406349 0.8204989  0.1254376 ]
# 0.8204989
# neutral
# [0.0706009  0.75235397 0.17704512]
# 0.75235397
# neutral
# [0.13303638 0.60490865 0.26205498]
# 0.60490865
# neutral
# 'togo' not in training corpus; ignoring.
# [0.12966678 0.5149212  0.3554121 ]
# 0.5149212
# neutral
# [0.15231082 0.43602702 0.41166216]
# 0.43602702
# neutral
# 'randomli' not in training corpus; ignoring.
# [0.06560239 0.8011193  0.13327827]
# 0.8011193
# neutral
# [0.10739163 0.6025136  0.29009476]
# 0.6025136
# neutral
# [0.20386654 0.35338578 0.44274765]
# 0.44274765
# positive
# [0.10207449 0.68683046 0.21109504]
# 0.68683046
# neutral
# 'jew' not in training corpus; ignoring.
# 'presbyterian' not in training corpus; ignoring.
# [0.16897024 0.4127445  0.4182853 ]
# 0.4182853
# positive
# [0.10674283 0.80000496 0.09325222]
# 0.80000496
# neutral
# [0.19184045 0.24989647 0.55826306]
# 0.55826306
# positive
# [0.11616752 0.54402584 0.33980662]
# 0.54402584
# neutral
# [0.13937698 0.52017486 0.3404481 ]
# 0.52017486
# neutral
# [0.09296083 0.10847153 0.79856765]
# 0.79856765
# positive
# 'lfc' not in training corpus; ignoring.
# [0.03284961 0.34526625 0.62188417]
# 0.62188417
# positive
# 'lovato' not in training corpus; ignoring.
# [0.1170809 0.4072935 0.4756256]
# 0.4756256
# positive
# [0.0982232  0.37396562 0.52781117]
# 0.52781117
# positive
# 'strategi' not in training corpus; ignoring.
# 'modera' not in training corpus; ignoring.
# [0.08881028 0.6628161  0.24837358]
# 0.6628161
# neutral
# [0.1320384  0.54603213 0.32192945]
# 0.54603213
# neutral
# 'brackett' not in training corpus; ignoring.
# 'overthrow' not in training corpus; ignoring.
# [0.14015096 0.6524475  0.20740148]
# 0.6524475
# neutral
# [0.05817438 0.17470782 0.7671178 ]
# 0.7671178
# positive
# [0.15420881 0.6104196  0.23537156]
# 0.6104196
# neutral
# [0.09805534 0.19236813 0.70957655]
# 0.70957655
# positive
# 'shld' not in training corpus; ignoring.
# 'fuk' not in training corpus; ignoring.
# [0.12974699 0.4013447  0.46890828]
# 0.46890828
# positive
# [0.18297382 0.46176502 0.35526112]
# 0.46176502
# neutral
# 'nikki' not in training corpus; ignoring.
# 'sustain' not in training corpus; ignoring.
# [0.19442266 0.4918474  0.3137299 ]
# 0.4918474
# neutral
# [0.1138833  0.42306373 0.46305296]
# 0.46305296
# positive
# 'sonic' not in training corpus; ignoring.
# [0.14121549 0.41483063 0.44395393]
# 0.44395393
# positive
# [0.19693826 0.38546357 0.41759816]
# 0.41759816
# positive
# [0.3580168  0.35063574 0.29134756]
# 0.3580168
# negative
# 'crunk' not in training corpus; ignoring.
# [0.3546644  0.27631742 0.3690182 ]
# 0.3690182
# positive
# 'brizo' not in training corpus; ignoring.
# [0.11855286 0.47414556 0.40730157]
# 0.47414556
# neutral
# 'jade' not in training corpus; ignoring.
# [0.1000837  0.18853833 0.71137804]
# 0.71137804
# positive
# 'chemistri' not in training corpus; ignoring.
# [0.14795068 0.04094955 0.81109977]
# 0.81109977
# positive
# 'ponder' not in training corpus; ignoring.
# [0.16826394 0.70657575 0.12516032]
# 0.70657575
# neutral
# 'igo' not in training corpus; ignoring.
# [0.1565308  0.4933825  0.35008672]
# 0.4933825
# neutral
# 'sevilla' not in training corpus; ignoring.
# [0.12771796 0.4749256  0.39735645]
# 0.4749256
# neutral
# 'terranc' not in training corpus; ignoring.
# 'cme' not in training corpus; ignoring.
# 'bluff' not in training corpus; ignoring.
# [0.19665463 0.57654876 0.22679661]
# 0.57654876
# neutral
# [0.05234516 0.6057022  0.34195262]
# 0.6057022
# neutral
# 'mcguin' not in training corpus; ignoring.
# 'stereotyp' not in training corpus; ignoring.
# [0.17370634 0.49772373 0.32856995]
# 0.49772373
# neutral
# 'singsnap' not in training corpus; ignoring.
# 'jclabb' not in training corpus; ignoring.
# [0.13396159 0.43913597 0.42690247]
# 0.43913597
# neutral
# [0.27089503 0.43100974 0.29809523]
# 0.43100974
# neutral
# 'turkey' not in training corpus; ignoring.
# [0.0876703  0.4003878  0.51194197]
# 0.51194197
# positive
# [0.18814887 0.47445717 0.33739385]
# 0.47445717
# neutral
# [0.11693313 0.29664922 0.5864176 ]
# 0.5864176
# positive
# [0.19480093 0.5528394  0.2523596 ]
# 0.5528394
# neutral
# 'marci' not in training corpus; ignoring.
# [0.0264465  0.01230109 0.96125233]
# 0.96125233
# positive
# [0.06121209 0.43465713 0.50413084]
# 0.50413084
# positive
# 'ath' not in training corpus; ignoring.
# [0.09991099 0.5271388  0.3729503 ]
# 0.5271388
# neutral
# [0.3610551  0.34350473 0.29544014]
# 0.3610551
# negative
# [0.05371849 0.5514464  0.3948352 ]
# 0.5514464
# neutral
# 'chimenti' not in training corpus; ignoring.
# [0.17145254 0.18773662 0.6408109 ]
# 0.6408109
# positive
# [0.15239343 0.5727537  0.27485284]
# 0.5727537
# neutral
# 'trilog' not in training corpus; ignoring.
# [0.11758583 0.70418257 0.1782316 ]
# 0.70418257
# neutral
# [0.17274156 0.15569519 0.67156327]
# 0.67156327
# positive
# 'danish' not in training corpus; ignoring.
# 'monitor' not in training corpus; ignoring.
# [0.1109474  0.7790106  0.11004205]
# 0.7790106
# neutral
# 'restor' not in training corpus; ignoring.
# 'mayfield' not in training corpus; ignoring.
# [0.10974582 0.5551163  0.3351379 ]
# 0.5551163
# neutral
# 'angelo' not in training corpus; ignoring.
# 'delic' not in training corpus; ignoring.
# [0.12826271 0.43069693 0.44104037]
# 0.44104037
# positive
# [0.46106848 0.3056579  0.23327366]
# 0.46106848
# negative
# [0.1518932  0.17602777 0.672079  ]
# 0.672079
# positive
# [0.17530768 0.46829292 0.35639942]
# 0.46829292
# neutral
# 'circu' not in training corpus; ignoring.
# [0.1280169  0.5784308  0.29355237]
# 0.5784308
# neutral
# 'rglll' not in training corpus; ignoring.
# [0.33626947 0.30036977 0.3633608 ]
# 0.3633608
# positive
# 'kennedi' not in training corpus; ignoring.
# [0.16225992 0.5895426  0.24819744]
# 0.5895426
# neutral
# 'olli' not in training corpus; ignoring.
# [0.05343845 0.45812476 0.48843673]
# 0.48843673
# positive
# 'shana' not in training corpus; ignoring.
# 'tovah' not in training corpus; ignoring.
# [0.00530451 0.00212637 0.99256915]
# 0.99256915
# positive
# 'elen' not in training corpus; ignoring.
# 'levon' not in training corpus; ignoring.
# [0.06456489 0.3050326  0.6304025 ]
# 0.6304025
# positive
# 'strictli' not in training corpus; ignoring.
# 'gunplay' not in training corpus; ignoring.
# 'pistol' not in training corpus; ignoring.
# [0.20847084 0.37488192 0.4166472 ]
# 0.4166472
# positive
# 'such' not in training corpus; ignoring.
# 'tulisa' not in training corpus; ignoring.
# [0.03148746 0.01284155 0.955671  ]
# 0.955671
# positive
# [0.10801464 0.0389494  0.8530359 ]
# 0.8530359
# positive
# [0.07634624 0.80017155 0.12348215]
# 0.80017155
# neutral
# [0.01153103 0.00351865 0.9849503 ]
# 0.9849503
# positive
# 'poet' not in training corpus; ignoring.
# [0.04929023 0.8538793  0.09683051]
# 0.8538793
# neutral
# 'slay' not in training corpus; ignoring.
# [0.11448497 0.669982   0.21553294]
# 0.669982
# neutral
# 'romin' not in training corpus; ignoring.
# [0.10732552 0.7902002  0.10247429]
# 0.7902002
# neutral
# [0.18041879 0.26560256 0.5539786 ]
# 0.5539786
# positive
# [0.22404137 0.44560716 0.3303514 ]
# 0.44560716
# neutral
# [0.22814317 0.3366285  0.43522832]
# 0.43522832
# positive
# 'properli' not in training corpus; ignoring.
# [0.13925567 0.3023887  0.5583556 ]
# 0.5583556
# positive
# [0.2408326 0.5511565 0.2080108]
# 0.5511565
# neutral
# [0.10334142 0.6764801  0.22017846]
# 0.6764801
# neutral
# [0.1750795  0.5787252  0.24619523]
# 0.5787252
# neutral
# 'outtak' not in training corpus; ignoring.
# [0.31294748 0.39311644 0.29393607]
# 0.39311644
# neutral
# 'giroud' not in training corpus; ignoring.
# [0.08954108 0.7187756  0.19168346]
# 0.7187756
# neutral
# [0.03046426 0.05170634 0.9178294 ]
# 0.9178294
# positive
# [0.14518087 0.7104973  0.14432177]
# 0.7104973
# neutral
# [0.10762861 0.5735176  0.31885374]
# 0.5735176
# neutral
# [0.09643046 0.279984   0.6235856 ]
# 0.6235856
# positive
# [0.05386777 0.07212755 0.8740047 ]
# 0.8740047
# positive
# 'exo' not in training corpus; ignoring.
# [0.13059229 0.5608989  0.30850878]
# 0.5608989
# neutral
# [0.13375022 0.37337095 0.4928789 ]
# 0.4928789
# positive
# 'below' not in training corpus; ignoring.
# 'whomadewho' not in training corpus; ignoring.
# [0.07208799 0.39801198 0.5299    ]
# 0.5299
# positive
# 'hof' not in training corpus; ignoring.
# [0.12216153 0.30671278 0.57112575]
# 0.57112575
# positive
# [0.16756521 0.23116724 0.6012676 ]
# 0.6012676
# positive
# [0.21240263 0.40916255 0.37843487]
# 0.40916255
# neutral
# [0.20386024 0.47119033 0.3249495 ]
# 0.47119033
# neutral
# 'shaquil' not in training corpus; ignoring.
# [0.04942877 0.1580567  0.79251456]
# 0.79251456
# positive
# 'decim' not in training corpus; ignoring.
# 'bullpen' not in training corpus; ignoring.
# [0.1361634  0.50732297 0.3565136 ]
# 0.50732297
# neutral
# 'grid' not in training corpus; ignoring.
# 'pregnanc' not in training corpus; ignoring.
# [0.24989875 0.29467273 0.45542857]
# 0.45542857
# positive
# 'craig' not in training corpus; ignoring.
# [0.17628652 0.5710972  0.25261632]
# 0.5710972
# neutral
# 'paulo' not in training corpus; ignoring.
# 'sousa' not in training corpus; ignoring.
# [0.20785886 0.65562505 0.13651611]
# 0.65562505
# neutral
# [0.0810452 0.1849597 0.7339951]
# 0.7339951
# positive
# [0.13552526 0.4486817  0.41579303]
# 0.4486817
# neutral
# 'laurel' not in training corpus; ignoring.
# [0.25706857 0.47754288 0.2653886 ]
# 0.47754288
# neutral
# 'juan' not in training corpus; ignoring.
# [0.07879595 0.30350733 0.6176967 ]
# 0.6176967
# positive
# [0.08564025 0.33728245 0.5770773 ]
# 0.5770773
# positive
# [0.05412079 0.4855733  0.4603059 ]
# 0.4855733
# neutral
# [0.1208868  0.70239854 0.17671466]
# 0.70239854
# neutral
# 'isaiah' not in training corpus; ignoring.
# 'moodi' not in training corpus; ignoring.
# 'fsu' not in training corpus; ignoring.
# [0.10508808 0.7168463  0.17806564]
# 0.7168463
# neutral
# 'harland' not in training corpus; ignoring.
# 'sander' not in training corpus; ignoring.
# [0.12032086 0.64325243 0.23642668]
# 0.64325243
# neutral
# [0.27616698 0.22909388 0.4947391 ]
# 0.4947391
# positive
# [0.15304908 0.66860616 0.1783447 ]
# 0.66860616
# neutral
# [0.24008998 0.30693674 0.4529733 ]
# 0.4529733
# positive
# [0.13438606 0.5564688  0.3091451 ]
# 0.5564688
# neutral
# 'salsa' not in training corpus; ignoring.
# 'y' not in training corpus; ignoring.
# [0.09726454 0.32992947 0.57280594]
# 0.57280594
# positive
# 'rj' not in training corpus; ignoring.
# [0.20359966 0.48210675 0.3142936 ]
# 0.48210675
# neutral
# 'wrangler' not in training corpus; ignoring.
# [0.15292916 0.57498515 0.2720857 ]
# 0.57498515
# neutral
# [0.07117784 0.54712456 0.38169762]
# 0.54712456
# neutral
# [0.1476468  0.23884071 0.6135125 ]
# 0.6135125
# positive
# 'auto' not in training corpus; ignoring.
# 'cmie' not in training corpus; ignoring.
# 'automobil' not in training corpus; ignoring.
# [0.16808721 0.6884525  0.14346035]
# 0.6884525
# neutral
# [0.03664873 0.11017397 0.8531773 ]
# 0.8531773
# positive
# 'supercharg' not in training corpus; ignoring.
# [0.21202362 0.5063866  0.2815898 ]
# 0.5063866
# neutral
# 'mullen' not in training corpus; ignoring.
# [0.12380321 0.5902858  0.28591102]
# 0.5902858
# neutral
# [0.10365085 0.15915863 0.73719054]
# 0.73719054
# positive
# [0.08943655 0.20460397 0.70595956]
# 0.70595956
# positive
# [0.02803803 0.03176647 0.94019544]
# 0.94019544
# positive
# [0.10122205 0.60421383 0.29456413]
# 0.60421383
# neutral
# 'woodi' not in training corpus; ignoring.
# [0.20707028 0.4757443  0.3171854 ]
# 0.4757443
# neutral
# [0.07776005 0.8201266  0.1021134 ]
# 0.8201266
# neutral
# 'guilti' not in training corpus; ignoring.
# [0.17409627 0.38777313 0.4381307 ]
# 0.4381307
# positive
# 'miinaj' not in training corpus; ignoring.
# 'robin' not in training corpus; ignoring.
# [0.06892283 0.05134846 0.8797287 ]
# 0.8797287
# positive
# [0.13368528 0.6094153  0.25689948]
# 0.6094153
# neutral
# 'daniela' not in training corpus; ignoring.
# [0.05719743 0.01836719 0.92443544]
# 0.92443544
# positive
# [0.08379272 0.06493159 0.8512756 ]
# 0.8512756
# positive
# 'petey' not in training corpus; ignoring.
# [0.09637526 0.61803734 0.2855873 ]
# 0.61803734
# neutral
# 'usf' not in training corpus; ignoring.
# [0.11952373 0.5494382  0.33103806]
# 0.5494382
# neutral
# [0.0886277  0.67656124 0.23481107]
# 0.67656124
# neutral
# [0.16070235 0.62241346 0.21688415]
# 0.62241346
# neutral
# 'directli' not in training corpus; ignoring.
# 'creepi' not in training corpus; ignoring.
# [0.17167212 0.594834   0.23349385]
# 0.594834
# neutral
# [0.06261843 0.15460865 0.7827729 ]
# 0.7827729
# positive
# [0.14235623 0.6939153  0.1637285 ]
# 0.6939153
# neutral
# 'tweetup' not in training corpus; ignoring.
# 'zubuchon' not in training corpus; ignoring.
# [0.00806524 0.0058449  0.9860898 ]
# 0.9860898
# positive
# [0.14016563 0.22969961 0.63013476]
# 0.63013476
# positive
# [0.13270557 0.7148757  0.15241869]
# 0.7148757
# neutral
# 'ironman' not in training corpus; ignoring.
# 'sneaki' not in training corpus; ignoring.
# 'glimps' not in training corpus; ignoring.
# [0.10462047 0.17503232 0.72034717]
# 0.72034717
# positive
# [0.04235427 0.14010389 0.81754184]
# 0.81754184
# positive
# [0.12730326 0.583582   0.28911468]
# 0.583582
# neutral
# 'bait' not in training corpus; ignoring.
# [0.09717017 0.5915325  0.31129736]
# 0.5915325
# neutral
# 'becca' not in training corpus; ignoring.
# [0.1096196 0.6209928 0.2693875]
# 0.6209928
# neutral
# [0.20989686 0.29704717 0.493056  ]
# 0.493056
# positive
# [0.24264553 0.5188386  0.23851582]
# 0.5188386
# neutral
# [0.09663858 0.3464374  0.55692405]
# 0.55692405
# positive
# 'relationship' not in training corpus; ignoring.
# [0.09627021 0.5114482  0.39228153]
# 0.5114482
# neutral
# 'depress' not in training corpus; ignoring.
# [0.12833661 0.5755705  0.2960928 ]
# 0.5755705
# neutral
# [0.04516895 0.75188893 0.20294216]
# 0.75188893
# neutral
# [0.29033047 0.42997688 0.27969265]
# 0.42997688
# neutral
# 'noah' not in training corpus; ignoring.
# 'stewart' not in training corpus; ignoring.
# 'margherita' not in training corpus; ignoring.
# [0.11107118 0.40784165 0.4810871 ]
# 0.4810871
# positive
# [0.12810971 0.15263171 0.7192586 ]
# 0.7192586
# positive
# [0.1034416  0.6384165  0.25814185]
# 0.6384165
# neutral
# [0.10312376 0.31833205 0.57854426]
# 0.57854426
# positive
# 'eyeshadow' not in training corpus; ignoring.
# 'smear' not in training corpus; ignoring.
# 'chunk' not in training corpus; ignoring.
# 'eyelash' not in training corpus; ignoring.
# [0.20375691 0.19925462 0.5969885 ]
# 0.5969885
# positive
# 'drag' not in training corpus; ignoring.
# [0.01020064 0.00386586 0.9859335 ]
# 0.9859335
# positive
# [0.11925941 0.6687428  0.21199782]
# 0.6687428
# neutral
# 'rokin' not in training corpus; ignoring.
# [0.09461848 0.5748403  0.33054128]
# 0.5748403
# neutral
# [0.1764458  0.23490396 0.5886502 ]
# 0.5886502
# positive
# 'sp' not in training corpus; ignoring.
# [0.04220123 0.75503474 0.20276405]
# 0.75503474
# neutral
# 'wankfest' not in training corpus; ignoring.
# [0.2331092  0.3747016  0.39218917]
# 0.39218917
# positive
# [0.20007543 0.2156919  0.5842326 ]
# 0.5842326
# positive
# 'preorder' not in training corpus; ignoring.
# [0.03981993 0.05096623 0.90921384]
# 0.90921384
# positive
# [0.02508333 0.15928897 0.81562775]
# 0.81562775
# positive
# [0.31474057 0.37083548 0.31442395]
# 0.37083548
# neutral
# [0.13510711 0.29807577 0.5668171 ]
# 0.5668171
# positive
# [0.10173485 0.7525297  0.1457355 ]
# 0.7525297
# neutral
# 'thay' not in training corpus; ignoring.
# [0.15276942 0.2016761  0.6455545 ]
# 0.6455545
# positive
# [0.10899549 0.34793985 0.5430647 ]
# 0.5430647
# positive
# [0.1971109  0.45532265 0.3475664 ]
# 0.45532265
# neutral
# [0.22572502 0.18165712 0.59261787]
# 0.59261787
# positive
# 'attende' not in training corpus; ignoring.
# [0.11751063 0.2160085  0.66648084]
# 0.66648084
# positive
# 'parson' not in training corpus; ignoring.
# 'tw' not in training corpus; ignoring.
# [0.08338369 0.58508086 0.33153546]
# 0.58508086
# neutral
# 'ooshma' not in training corpus; ignoring.
# 'garg' not in training corpus; ignoring.
# [0.11306674 0.25158423 0.635349  ]
# 0.635349
# positive
# [0.06983984 0.8291747  0.10098545]
# 0.8291747
# neutral
# [0.12101852 0.6725558  0.2064256 ]
# 0.6725558
# neutral
# 'ie' not in training corpus; ignoring.
# 'dia' not in training corpus; ignoring.
# [0.15417153 0.63498384 0.21084458]
# 0.63498384
# neutral
# 'vintag' not in training corpus; ignoring.
# [0.1121175  0.7311536  0.15672885]
# 0.7311536
# neutral
# [0.03729846 0.90837216 0.05432934]
# 0.90837216
# neutral
# 'jelli' not in training corpus; ignoring.
# [0.18926747 0.30502316 0.50570935]
# 0.50570935
# positive
# [0.11449561 0.4756117  0.4098927 ]
# 0.4756117
# neutral
# 'prizefight' not in training corpus; ignoring.
# [0.08267127 0.29119042 0.6261383 ]
# 0.6261383
# positive
# 'curto' not in training corpus; ignoring.
# 'fairli' not in training corpus; ignoring.
# [0.27453634 0.5413347  0.18412901]
# 0.5413347
# neutral
# [0.25950813 0.2886746  0.45181724]
# 0.45181724
# positive
# 'snake' not in training corpus; ignoring.
# [0.13445698 0.40682557 0.4587175 ]
# 0.4587175
# positive
# [0.12620638 0.15144941 0.7223442 ]
# 0.7223442
# positive
# 'seemingli' not in training corpus; ignoring.
# [0.13415164 0.57169914 0.29414925]
# 0.57169914
# neutral
# 'brush' not in training corpus; ignoring.
# [0.11155462 0.43499032 0.4534551 ]
# 0.4534551
# positive
# [0.12640841 0.6120442  0.26154742]
# 0.6120442
# neutral
# [0.23602632 0.11931159 0.6446621 ]
# 0.6446621
# positive
# 'hellllll' not in training corpus; ignoring.
# [0.3864977  0.48158762 0.13191468]
# 0.48158762
# neutral
# [0.15150847 0.42291215 0.42557943]
# 0.42557943
# positive
# [0.16956715 0.43958503 0.39084786]
# 0.43958503
# neutral
# [0.08844369 0.67117846 0.24037784]
# 0.67117846
# neutral
# 'ave' not in training corpus; ignoring.
# 'canal' not in training corpus; ignoring.
# [0.14748535 0.60744715 0.24506748]
# 0.60744715
# neutral
# [0.0414698  0.46939066 0.48913953]
# 0.48913953
# positive
# [0.09768398 0.7393827  0.1629333 ]
# 0.7393827
# neutral
# [0.10178106 0.7372138  0.16100517]
# 0.7372138
# neutral
# 'todoroff' not in training corpus; ignoring.
# [0.04045743 0.8183279  0.14121464]
# 0.8183279
# neutral
# 'theyr' not in training corpus; ignoring.
# [0.17282377 0.49085903 0.33631718]
# 0.49085903
# neutral
# 'edinburgh' not in training corpus; ignoring.
# 'cit' not in training corpus; ignoring.
# [0.07852094 0.68542457 0.23605451]
# 0.68542457
# neutral
# 'abov' not in training corpus; ignoring.
# [0.06853287 0.6030614  0.32840574]
# 0.6030614
# neutral
# 'saxon' not in training corpus; ignoring.
# 'megadeth' not in training corpus; ignoring.
# [0.07538768 0.5698534  0.35475886]
# 0.5698534
# neutral
# 'byng' not in training corpus; ignoring.
# [0.22415939 0.495055   0.2807856 ]
# 0.495055
# neutral
# 'durabl' not in training corpus; ignoring.
# 'yao' not in training corpus; ignoring.
# [0.16490497 0.04301973 0.7920753 ]
# 0.7920753
# positive
# [0.0678222  0.715595   0.21658283]
# 0.715595
# neutral
# [0.15625003 0.43465853 0.4090914 ]
# 0.43465853
# neutral
# [0.1067847  0.691361   0.20185433]
# 0.691361
# neutral
# 'brag' not in training corpus; ignoring.
# [0.22874656 0.2890435  0.4822099 ]
# 0.4822099
# positive
# [0.1366327  0.31792334 0.54544395]
# 0.54544395
# positive
# [0.19835654 0.52825284 0.2733906 ]
# 0.52825284
# neutral
# 'revercomb' not in training corpus; ignoring.
# 'potluck' not in training corpus; ignoring.
# [0.07191622 0.35393712 0.5741466 ]
# 0.5741466
# positive
# 'kershaw' not in training corpus; ignoring.
# 'inbox' not in training corpus; ignoring.
# [0.08917145 0.7949292  0.11589931]
# 0.7949292
# neutral
# 'undercard' not in training corpus; ignoring.
# [0.14240818 0.10980245 0.7477893 ]
# 0.7477893
# positive
# 'rattlestick' not in training corpus; ignoring.
# 'jcc' not in training corpus; ignoring.
# [0.09133726 0.5698818  0.33878094]
# 0.5698818
# neutral
# 'toowoomba' not in training corpus; ignoring.
# [0.06490772 0.09074334 0.8443489 ]
# 0.8443489
# positive
# [0.12652484 0.66734356 0.20613158]
# 0.66734356
# neutral
# [0.1088994  0.31723288 0.57386774]
# 0.57386774
# positive
# 'mthd' not in training corpus; ignoring.
# 'gothic' not in training corpus; ignoring.
# [0.05587812 0.65822226 0.28589964]
# 0.65822226
# neutral
# [0.09105214 0.64846987 0.260478  ]
# 0.64846987
# neutral
# 'goti' not in training corpus; ignoring.
# [0.20293228 0.21039161 0.58667606]
# 0.58667606
# positive
# 'crazzzzyy' not in training corpus; ignoring.
# [0.23844302 0.15258871 0.60896826]
# 0.60896826
# positive
# [0.36928263 0.19665447 0.43406284]
# 0.43406284
# positive
# [0.33212003 0.20114936 0.4667306 ]
# 0.4667306
# positive
# 'befit' not in training corpus; ignoring.
# [0.04806058 0.5924168  0.35952255]
# 0.5924168
# neutral
# [0.0514808  0.06491467 0.8836045 ]
# 0.8836045
# positive
# 'convert' not in training corpus; ignoring.
# [0.13573058 0.6229773  0.2412921 ]
# 0.6229773
# neutral
# [0.1413507  0.1381859  0.72046345]
# 0.72046345
# positive
# [0.05393002 0.5845205  0.36154953]
# 0.5845205
# neutral
# 'shammi' not in training corpus; ignoring.
# [0.13625304 0.73569214 0.1280548 ]
# 0.73569214
# neutral
# [0.38252574 0.17676976 0.44070452]
# 0.44070452
# positive
# 'skirmish' not in training corpus; ignoring.
# [0.16427697 0.3207693  0.5149537 ]
# 0.5149537
# positive
# [0.10049895 0.6940278  0.20547324]
# 0.6940278
# neutral
# 'div' not in training corpus; ignoring.
# [0.20893495 0.35036853 0.44069648]
# 0.44069648
# positive
# [0.05384667 0.49836302 0.4477902 ]
# 0.49836302
# neutral
# [0.02111953 0.19904625 0.7798342 ]
# 0.7798342
# positive
# 'biographi' not in training corpus; ignoring.
# [0.20767333 0.32322097 0.4691057 ]
# 0.4691057
# positive
# 'reciev' not in training corpus; ignoring.
# [0.16551301 0.19386406 0.640623  ]
# 0.640623
# positive
# 'thrash' not in training corpus; ignoring.
# [0.11272477 0.39690524 0.49036998]
# 0.49036998
# positive
# 'leaf' not in training corpus; ignoring.
# 'warner' not in training corpus; ignoring.
# [0.14003143 0.73746884 0.12249979]
# 0.73746884
# neutral
# [0.27085656 0.38318282 0.3459606 ]
# 0.38318282
# neutral
# 'fredonia' not in training corpus; ignoring.
# [0.09068981 0.6946708  0.21463938]
# 0.6946708
# neutral
# [0.09096245 0.35301235 0.55602515]
# 0.55602515
# positive
# 'eunha' not in training corpus; ignoring.
# 'icn' not in training corpus; ignoring.
# [0.18611634 0.34700796 0.4668757 ]
# 0.4668757
# positive
# [0.06658744 0.8388238  0.09458872]
# 0.8388238
# neutral
# [0.05601609 0.16746838 0.77651554]
# 0.77651554
# positive
# [0.44741532 0.26152128 0.29106337]
# 0.44741532
# negative
# [0.14469506 0.47074774 0.38455722]
# 0.47074774
# neutral
# [0.12461357 0.7343811  0.14100537]
# 0.7343811
# neutral
# 'accomplish' not in training corpus; ignoring.
# [2.5076063e-03 7.5709075e-04 9.9673527e-01]
# 0.9967353
# positive
# 'occas' not in training corpus; ignoring.
# [0.07240681 0.56605494 0.36153826]
# 0.56605494
# neutral
# [0.22870837 0.27483216 0.49645945]
# 0.49645945
# positive
# 'dmdk' not in training corpus; ignoring.
# 'vijayakanth' not in training corpus; ignoring.
# 'sustain' not in training corpus; ignoring.
# 'shrewd' not in training corpus; ignoring.
# [0.15163818 0.49873066 0.34963104]
# 0.49873066
# neutral
# 'jacinto' not in training corpus; ignoring.
# 'guardian' not in training corpus; ignoring.
# 'fer' not in training corpus; ignoring.
# [0.12581408 0.6228134  0.25137258]
# 0.6228134
# neutral
# 'recruit' not in training corpus; ignoring.
# [0.17502844 0.24631162 0.57865995]
# 0.57865995
# positive
# [0.19732639 0.6528615  0.14981212]
# 0.6528615
# neutral
# [0.11865776 0.55568564 0.3256566 ]
# 0.55568564
# neutral
# [0.23261592 0.04875596 0.7186281 ]
# 0.7186281
# positive
# [0.02474597 0.03692331 0.9383307 ]
# 0.9383307
# positive
# 'overjoy' not in training corpus; ignoring.
# [0.03499468 0.0166779  0.9483275 ]
# 0.9483275
# positive
# 'loo' not in training corpus; ignoring.
# 'romford' not in training corpus; ignoring.
# [0.18408053 0.5242494  0.29167002]
# 0.5242494
# neutral
# [0.07544437 0.19345583 0.7310998 ]
# 0.7310998
# positive
# 'shyte' not in training corpus; ignoring.
# 'ouuta' not in training corpus; ignoring.
# 'truust' not in training corpus; ignoring.
# 'getchu' not in training corpus; ignoring.
# [0.17767788 0.51798296 0.30433917]
# 0.51798296
# neutral
# [0.1791504  0.5389541  0.28189552]
# 0.5389541
# neutral
# [0.08926106 0.7825445  0.1281944 ]
# 0.7825445
# neutral
# [0.13191469 0.54237175 0.32571357]
# 0.54237175
# neutral
# [0.10378849 0.70317173 0.19303975]
# 0.70317173
# neutral
# 'stranger' not in training corpus; ignoring.
# [0.16583122 0.51845604 0.31571272]
# 0.51845604
# neutral
# 'interchang' not in training corpus; ignoring.
# 'tilt' not in training corpus; ignoring.
# [0.06677803 0.81127465 0.1219474 ]
# 0.81127465
# neutral
# 'paradis' not in training corpus; ignoring.
# [0.09240033 0.32634673 0.581253  ]
# 0.581253
# positive
# 'lynchburg' not in training corpus; ignoring.
# [0.11311746 0.21875082 0.66813177]
# 0.66813177
# positive
# [0.16508794 0.49018103 0.3447311 ]
# 0.49018103
# neutral
# [0.06617828 0.259396   0.6744258 ]
# 0.6744258
# positive
# [0.1365204  0.6199623  0.24351735]
# 0.6199623
# neutral
# [0.0933698  0.40183714 0.5047931 ]
# 0.5047931
# positive
# 'oasisedmonton' not in training corpus; ignoring.
# 'sunpoor' not in training corpus; ignoring.
# [0.12012511 0.57888556 0.30098936]
# 0.57888556
# neutral
# 'shane' not in training corpus; ignoring.
# [0.35010907 0.33715013 0.3127408 ]
# 0.35010907
# negative
# [0.14739892 0.53658533 0.31601575]
# 0.53658533
# neutral
# [0.09204941 0.19276254 0.715188  ]
# 0.715188
# positive
# 'gloam' not in training corpus; ignoring.
# [0.13566287 0.64011616 0.22422093]
# 0.64011616
# neutral
# 'cowork' not in training corpus; ignoring.
# [0.30046204 0.34583864 0.3536993 ]
# 0.3536993
# positive
# 'tcaformiley' not in training corpus; ignoring.
# [0.09916408 0.61530083 0.2855351 ]
# 0.61530083
# neutral
# [0.13559327 0.68674284 0.1776639 ]
# 0.68674284
# neutral
# 'burden' not in training corpus; ignoring.
# [0.2776653 0.4299664 0.2923683]
# 0.4299664
# neutral
# [0.19023205 0.45578793 0.35398006]
# 0.45578793
# neutral
# [0.23316282 0.34193316 0.42490396]
# 0.42490396
# positive
# 'hv' not in training corpus; ignoring.
# 'hv' not in training corpus; ignoring.
# 'killem' not in training corpus; ignoring.
# [0.1990759  0.44158    0.35934407]
# 0.44158
# neutral
# [0.08270482 0.7845718  0.13272345]
# 0.7845718
# neutral
# [0.19383088 0.49525252 0.31091654]
# 0.49525252
# neutral
# [0.2312118  0.23758075 0.5312075 ]
# 0.5312075
# positive
# [0.13946585 0.4079876  0.45254648]
# 0.45254648
# positive
# 'udar' not in training corpus; ignoring.
# 'potemkin' not in training corpus; ignoring.
# [0.13798311 0.6549618  0.2070551 ]
# 0.6549618
# neutral
# 'loveabl' not in training corpus; ignoring.
# [0.0529625  0.05395961 0.89307785]
# 0.89307785
# positive
# 'kj' not in training corpus; ignoring.
# [0.16635062 0.57281536 0.26083395]
# 0.57281536
# neutral
# [0.06298237 0.21746948 0.7195482 ]
# 0.7195482
# positive
# 'jumbi' not in training corpus; ignoring.
# 'thirsti' not in training corpus; ignoring.
# 'turtl' not in training corpus; ignoring.
# [0.10181674 0.49633837 0.40184486]
# 0.49633837
# neutral
# [0.15047793 0.52139145 0.32813057]
# 0.52139145
# neutral
# [0.24090505 0.41388044 0.3452145 ]
# 0.41388044
# neutral
# [0.0561028  0.36181524 0.582082  ]
# 0.582082
# positive
# 'epi' not in training corpus; ignoring.
# [0.4070569  0.28526095 0.3076822 ]
# 0.4070569
# negative
# [0.16243339 0.48507726 0.35248938]
# 0.48507726
# neutral
# 'wjct' not in training corpus; ignoring.
# [0.07818749 0.11995208 0.8018604 ]
# 0.8018604
# positive
# 'foulk' not in training corpus; ignoring.
# 'rli' not in training corpus; ignoring.
# [0.15888768 0.47713414 0.3639782 ]
# 0.47713414
# neutral
# [0.08221541 0.06672412 0.8510604 ]
# 0.8510604
# positive
# 'squint' not in training corpus; ignoring.
# [0.19357096 0.46185905 0.34457   ]
# 0.46185905
# neutral
# 'curb' not in training corpus; ignoring.
# [0.12277135 0.5176214  0.35960725]
# 0.5176214
# neutral
# [0.30870056 0.2749276  0.41637185]
# 0.41637185
# positive
# 'roubaix' not in training corpus; ignoring.
# [0.14832368 0.57645136 0.2752249 ]
# 0.57645136
# neutral
# 'currenc' not in training corpus; ignoring.
# [0.05939014 0.10824437 0.8323655 ]
# 0.8323655
# positive
# 'fausto' not in training corpus; ignoring.
# 'carmona' not in training corpus; ignoring.
# [0.10862751 0.5913353  0.30003724]
# 0.5913353
# neutral
# [0.01032647 0.00797276 0.98170084]
# 0.98170084
# positive
# [0.02713251 0.08861718 0.8842502 ]
# 0.8842502
# positive
# 'fungal' not in training corpus; ignoring.
# 'spore' not in training corpus; ignoring.
# 'dispers' not in training corpus; ignoring.
# 'tori' not in training corpus; ignoring.
# 'lederhosen' not in training corpus; ignoring.
# [0.14486274 0.5330288  0.32210842]
# 0.5330288
# neutral
# 'superstiti' not in training corpus; ignoring.
# [0.23154151 0.17664471 0.59181374]
# 0.59181374
# positive
# 'dutch' not in training corpus; ignoring.
# 'tapet' not in training corpus; ignoring.
# [0.14287749 0.47337937 0.38374314]
# 0.47337937
# neutral
# [0.13989796 0.47241378 0.38768822]
# 0.47241378
# neutral
# [0.05281904 0.23359507 0.71358585]
# 0.71358585
# positive
# [0.04846859 0.13618022 0.8153512 ]
# 0.8153512
# positive
# 'tower' not in training corpus; ignoring.
# [0.17284001 0.5554122  0.2717479 ]
# 0.5554122
# neutral
# [0.08988158 0.37012884 0.5399896 ]
# 0.5399896
# positive
# [0.08797672 0.06120589 0.8508173 ]
# 0.8508173
# positive
# 'summon' not in training corpus; ignoring.
# 'mol' not in training corpus; ignoring.
# [0.18578096 0.39194363 0.42227536]
# 0.42227536
# positive
# 'postag' not in training corpus; ignoring.
# [0.10191228 0.69725883 0.20082892]
# 0.69725883
# neutral
# [0.10879146 0.05575534 0.8354532 ]
# 0.8354532
# positive
# [0.13910955 0.5947315  0.2661589 ]
# 0.5947315
# neutral
# 'gene' not in training corpus; ignoring.
# 'stephenson' not in training corpus; ignoring.
# 'boil' not in training corpus; ignoring.
# [0.19821924 0.34170118 0.46007958]
# 0.46007958
# positive
# [0.07082964 0.8251864  0.10398392]
# 0.8251864
# neutral
# [0.13930307 0.20705573 0.6536412 ]
# 0.6536412
# positive
# 'mcallen' not in training corpus; ignoring.
# [0.06666053 0.47199115 0.46134833]
# 0.47199115
# neutral
# [0.12741128 0.5801978  0.29239088]
# 0.5801978
# neutral
# 'redirect' not in training corpus; ignoring.
# [0.09895645 0.32639235 0.57465124]
# 0.57465124
# positive
# 'airwav' not in training corpus; ignoring.
# [0.0432838  0.10400607 0.8527102 ]
# 0.8527102
# positive
# [0.14822856 0.32723832 0.5245331 ]
# 0.5245331
# positive
# 'mixtap' not in training corpus; ignoring.
# [0.18410553 0.46904668 0.3468478 ]
# 0.46904668
# neutral
# [0.00717657 0.00273858 0.9900849 ]
# 0.9900849
# positive
# [0.22075926 0.5560988  0.22314198]
# 0.5560988
# neutral
# 'sheeran' not in training corpus; ignoring.
# 'perf' not in training corpus; ignoring.
# [0.13201661 0.39193505 0.4760483 ]
# 0.4760483
# positive
# [0.11864331 0.37725607 0.5041007 ]
# 0.5041007
# positive
# 'goldfish' not in training corpus; ignoring.
# [0.06184535 0.5113168  0.42683792]
# 0.5113168
# neutral
# [0.12401216 0.70070964 0.17527817]
# 0.70070964
# neutral
# 'qia' not in training corpus; ignoring.
# [0.11244551 0.4412194  0.44633502]
# 0.44633502
# positive
# [0.23645  0.437796 0.325754]
# 0.437796
# neutral
# 'serenad' not in training corpus; ignoring.
# [0.13296355 0.06373492 0.8033015 ]
# 0.8033015
# positive
# 'merson' not in training corpus; ignoring.
# [0.15194254 0.7437141  0.10434339]
# 0.7437141
# neutral
# [0.01671731 0.06671315 0.9165695 ]
# 0.9165695
# positive
# [0.20894241 0.5715487  0.21950884]
# 0.5715487
# neutral
# 'tenaci' not in training corpus; ignoring.
# [0.06261879 0.5508293  0.3865519 ]
# 0.5508293
# neutral
# [0.09560778 0.6780182  0.22637402]
# 0.6780182
# neutral
# [0.23307174 0.54100686 0.22592136]
# 0.54100686
# neutral
# [0.19061199 0.22207528 0.58731276]
# 0.58731276
# positive
# 'lowdown' not in training corpus; ignoring.
# 'strictli' not in training corpus; ignoring.
# [0.14406739 0.4916319  0.3643007 ]
# 0.4916319
# neutral
# 'cinemonkey' not in training corpus; ignoring.
# [0.0531751  0.20125574 0.74556917]
# 0.74556917
# positive
# 'vuitton' not in training corpus; ignoring.
# [0.122788   0.48051813 0.39669383]
# 0.48051813
# neutral
# [0.12742966 0.3852432  0.48732716]
# 0.48732716
# positive
# [0.20857641 0.5327439  0.25867978]
# 0.5327439
# neutral
# [0.19112459 0.4276529  0.38122258]
# 0.4276529
# neutral
# 'indhi' not in training corpus; ignoring.
# ...
# [0.10401484 0.65696275 0.23902245]
# 0.65696275
# neutral
# [0.14908552 0.73435515 0.11655927]
# 0.73435515
# neutral
# [0.195708   0.47980398 0.32448792]
# 0.47980398
# neutral
# 'galleri' not in training corpus; ignoring.
# [0.02741588 0.08974734 0.88283676]
# 0.88283676
# positive
# [0.08274161 0.49321687 0.42404154]
# 0.49321687
# neutral
# 'saigon' not in training corpus; ignoring.
# [0.05525995 0.60930115 0.3354389 ]
# 0.60930115
# neutral
# [0.07152817 0.17930996 0.74916184]
# 0.74916184
# positive
# [0.07266997 0.27122992 0.65610003]
# 0.65610003
# positive
# 'brandenberg' not in training corpus; ignoring.
# [0.29594296 0.39209718 0.31195983]
# 0.39209718
# neutral
# 'coliseum' not in training corpus; ignoring.
# [0.06666187 0.6994087  0.23392943]
# 0.6994087
# neutral
# [0.22168583 0.38236803 0.39594617]
# 0.39594617
# positive
# [0.10869309 0.4233057  0.46800125]
# 0.46800125
# positive
# 'aplog' not in training corpus; ignoring.
# 'tardi' not in training corpus; ignoring.
# [0.2295501  0.54751146 0.22293845]
# 0.54751146
# neutral
# 'clarifi' not in training corpus; ignoring.
# [0.21510515 0.51485085 0.27004403]
# 0.51485085
# neutral
# 'castrat' not in training corpus; ignoring.
# [0.2245361  0.48806718 0.28739664]
# 0.48806718
# neutral
# [0.03764336 0.10044226 0.86191434]
# 0.86191434
# positive
# [0.16784649 0.52334666 0.30880687]
# 0.52334666
# neutral
# [0.10578602 0.1507486  0.7434654 ]
# 0.7434654
# positive
# [0.11271798 0.71118665 0.1760954 ]
# 0.71118665
# neutral
# [0.2129378  0.6103854  0.17667684]
# 0.6103854
# neutral
# 'tay' not in training corpus; ignoring.
# [0.1060357  0.7139672  0.17999709]
# 0.7139672
# neutral
# 'intercept' not in training corpus; ignoring.
# 'mccray' not in training corpus; ignoring.
# [0.14219317 0.5525263  0.3052806 ]
# 0.5525263
# neutral
# [0.04506643 0.83933294 0.11560064]
# 0.83933294
# neutral
# 'ballot' not in training corpus; ignoring.
# [0.12130747 0.03744641 0.84124607]
# 0.84124607
# positive
# [0.12076984 0.5559751  0.32325506]
# 0.5559751
# neutral
# 'compla' not in training corpus; ignoring.
# 'allll' not in training corpus; ignoring.
# [0.2739998  0.19519208 0.53080803]
# 0.53080803
# positive
# 'remembr' not in training corpus; ignoring.
# 'hagedorn' not in training corpus; ignoring.
# [0.0627996  0.646616   0.29058442]
# 0.646616
# neutral
# [0.09110664 0.38755262 0.5213408 ]
# 0.5213408
# positive
# [0.07688984 0.10444695 0.81866324]
# 0.81866324
# positive
# 'shap' not in training corpus; ignoring.
# [0.12013356 0.35195848 0.52790797]
# 0.52790797
# positive
# 'fewer' not in training corpus; ignoring.
# [0.09704991 0.37638998 0.5265601 ]
# 0.5265601
# positive
# 'resist' not in training corpus; ignoring.
# [0.24653938 0.5567565  0.19670413]
# 0.5567565
# neutral
# [0.09935731 0.6789356  0.22170706]
# 0.6789356
# neutral
# [0.03371377 0.06559103 0.90069515]
# 0.90069515
# positive
# 'ow' not in training corpus; ignoring.
# [0.09051321 0.651258   0.2582288 ]
# 0.651258
# neutral
# [0.15405326 0.61013764 0.23580915]
# 0.61013764
# neutral
# [0.07574252 0.08160076 0.84265673]
# 0.84265673
# positive
# [0.10805409 0.59828705 0.29365885]
# 0.59828705
# neutral
# 'awhil' not in training corpus; ignoring.
# [0.14898437 0.5286659  0.3223498 ]
# 0.5286659
# neutral
# 'ashevil' not in training corpus; ignoring.
# [0.07247869 0.24896319 0.6785582 ]
# 0.6785582
# positive
# 'leonardo' not in training corpus; ignoring.
# [0.10687158 0.38561162 0.5075168 ]
# 0.5075168
# positive
# 'uppc' not in training corpus; ignoring.
# [0.26645803 0.15645926 0.5770827 ]
# 0.5770827
# positive
# [0.13944982 0.29243407 0.56811607]
# 0.56811607
# positive
# 'thirsti' not in training corpus; ignoring.
# [0.20392036 0.38693607 0.4091436 ]
# 0.4091436
# positive
# [0.02413945 0.04301137 0.93284917]
# 0.93284917
# positive
# [0.03184289 0.08303396 0.8851232 ]
# 0.8851232
# positive
# 'demba' not in training corpus; ignoring.
# 'claus' not in training corpus; ignoring.
# [0.15951136 0.4219269  0.41856176]
# 0.4219269
# neutral
# [0.02105021 0.0575936  0.9213562 ]
# 0.9213562
# positive
# [0.15950324 0.62065583 0.21984096]
# 0.62065583
# neutral
# [0.36208293 0.26710707 0.37081   ]
# 0.37081
# positive
# [0.18874146 0.5310756  0.28018296]
# 0.5310756
# neutral
# 'ooosh' not in training corpus; ignoring.
# [0.04034097 0.03288051 0.92677855]
# 0.92677855
# positive
# 'blunt' not in training corpus; ignoring.
# [0.12192005 0.4664764  0.4116036 ]
# 0.4664764
# neutral
# 'bermudez' not in training corpus; ignoring.
# 'launchpad' not in training corpus; ignoring.
# [0.06069799 0.5686341  0.37066802]
# 0.5686341
# neutral
# [0.08309183 0.7505424  0.16636573]
# 0.7505424
# neutral
# [0.1425916  0.57764953 0.27975887]
# 0.57764953
# neutral
# 'submiss' not in training corpus; ignoring.
# [0.23336154 0.41325045 0.35338798]
# 0.41325045
# neutral
# [0.12049408 0.5206527  0.35885325]
# 0.5206527
# neutral
# 'damian' not in training corpus; ignoring.
# 'lillard' not in training corpus; ignoring.
# [0.16731943 0.4154955  0.41718504]
# 0.41718504
# positive
# 'dubstep' not in training corpus; ignoring.
# [0.044264   0.6720781  0.28365785]
# 0.6720781
# neutral
# [0.10348668 0.465652   0.43086126]
# 0.465652
# neutral
# 'icloud' not in training corpus; ignoring.
# [0.21771425 0.6338349  0.1484509 ]
# 0.6338349
# neutral
# [0.0820787  0.70668566 0.21123566]
# 0.70668566
# neutral
# 'corral' not in training corpus; ignoring.
# [0.13800251 0.47271135 0.38928616]
# 0.47271135
# neutral
# [0.08176513 0.65594983 0.262285  ]
# 0.65594983
# neutral
# [0.16111211 0.27844605 0.5604418 ]
# 0.5604418
# positive
# [0.13413328 0.63423955 0.23162709]
# 0.63423955
# neutral
# 'such' not in training corpus; ignoring.
# [0.06964093 0.10600012 0.82435894]
# 0.82435894
# positive
# [0.2760448  0.23182943 0.49212575]
# 0.49212575
# positive
# [0.23198818 0.39076596 0.3772459 ]
# 0.39076596
# neutral
# [0.17177105 0.1970039  0.631225  ]
# 0.631225
# positive
# 'exploratori' not in training corpus; ignoring.
# 'pinpoint' not in training corpus; ignoring.
# 'discomfort' not in training corpus; ignoring.
# [0.1628272 0.4233157 0.4138571]
# 0.4233157
# neutral
# [0.09112603 0.4791451  0.42972887]
# 0.4791451
# neutral
# [0.11975597 0.65180653 0.22843751]
# 0.65180653
# neutral
# 'ethan' not in training corpus; ignoring.
# [0.20316675 0.3631264  0.43370685]
# 0.43370685
# positive
# 'benefici' not in training corpus; ignoring.
# 'clog' not in training corpus; ignoring.
# [0.19435136 0.5840167  0.22163188]
# 0.5840167
# neutral
# 'miguel' not in training corpus; ignoring.
# 'beermen' not in training corpus; ignoring.
# [0.08503305 0.50451267 0.41045424]
# 0.50451267
# neutral
# [0.14457543 0.3693687  0.48605588]
# 0.48605588
# positive
# [0.08026901 0.30468032 0.6150506 ]
# 0.6150506
# positive
# 'supposedli' not in training corpus; ignoring.
# 'celsiu' not in training corpus; ignoring.
# [0.12256657 0.68802327 0.18941024]
# 0.68802327
# neutral
# [0.05419498 0.8833021  0.06250286]
# 0.8833021
# neutral
# [0.12631825 0.53084034 0.34284142]
# 0.53084034
# neutral
# 'explan' not in training corpus; ignoring.
# 'huh' not in training corpus; ignoring.
# [0.24232712 0.19657122 0.5611017 ]
# 0.5611017
# positive
# 'luxford' not in training corpus; ignoring.
# [0.14765759 0.597784   0.25455835]
# 0.597784
# neutral
# [0.06008169 0.49019477 0.4497235 ]
# 0.49019477
# neutral
# [0.24341762 0.43527249 0.3213099 ]
# 0.43527249
# neutral
# [0.04256245 0.81020075 0.14723675]
# 0.81020075
# neutral
# [0.11850882 0.47860345 0.40288776]
# 0.47860345
# neutral
# 'gumbi' not in training corpus; ignoring.
# [0.21935254 0.19462569 0.5860217 ]
# 0.5860217
# positive
# [0.10102663 0.57506835 0.32390496]
# 0.57506835
# neutral
# [0.12784094 0.48530895 0.3868501 ]
# 0.48530895
# neutral
# 'hamel' not in training corpus; ignoring.
# [0.1067744  0.7439061  0.14931956]
# 0.7439061
# neutral
# [0.0604142  0.8345234  0.10506246]
# 0.8345234
# neutral
# 'oth' not in training corpus; ignoring.
# [0.04744727 0.02228973 0.9302629 ]
# 0.9302629
# positive
# [0.28522414 0.35769075 0.35708508]
# 0.35769075
# neutral
# [0.13488738 0.477616   0.38749665]
# 0.477616
# neutral
# [0.10916737 0.27334452 0.6174881 ]
# 0.6174881
# positive
# 'innoc' not in training corpus; ignoring.
# 'gin' not in training corpus; ignoring.
# [0.66022044 0.18162735 0.15815215]
# 0.66022044
# negative
# [0.10582178 0.67179215 0.22238606]
# 0.67179215
# neutral
# 'omit' not in training corpus; ignoring.
# 'vaccin' not in training corpus; ignoring.
# [0.30173895 0.5052334  0.19302756]
# 0.5052334
# neutral
# 'eagel' not in training corpus; ignoring.
# [0.09464486 0.53869843 0.36665675]
# 0.53869843
# neutral
# 'metormix' not in training corpus; ignoring.
# [0.09184591 0.45303974 0.45511428]
# 0.45511428
# positive
# [0.09582097 0.59475577 0.30942327]
# 0.59475577
# neutral
# [0.1140333  0.5780109  0.30795574]
# 0.5780109
# neutral
# 'chap' not in training corpus; ignoring.
# [0.08491228 0.7246454  0.19044235]
# 0.7246454
# neutral
# 'tap' not in training corpus; ignoring.
# [0.08653671 0.14088166 0.77258164]
# 0.77258164
# positive
# [0.15219878 0.5582694  0.28953192]
# 0.5582694
# neutral
# 'dwc' not in training corpus; ignoring.
# 'raphael' not in training corpus; ignoring.
# [0.08783811 0.4256457  0.48651615]
# 0.48651615
# positive
# [0.19412997 0.48081115 0.32505882]
# 0.48081115
# neutral
# [0.10634097 0.765822   0.12783708]
# 0.765822
# neutral
# 'zero' not in training corpus; ignoring.
# [0.11193533 0.46238092 0.42568377]
# 0.46238092
# neutral
# [0.03677903 0.0365264  0.9266946 ]
# 0.9266946
# positive
# 'amgen' not in training corpus; ignoring.
# [0.00750503 0.01147008 0.98102486]
# 0.98102486
# positive
# 'snowi' not in training corpus; ignoring.
# [0.03294064 0.08901069 0.87804866]
# 0.87804866
# positive
# [0.07844987 0.7810559  0.14049426]
# 0.7810559
# neutral
# 'incens' not in training corpus; ignoring.
# [0.1409777  0.15381363 0.70520866]
# 0.70520866
# positive
# 'banjo' not in training corpus; ignoring.
# [0.08426645 0.22846162 0.68727183]
# 0.68727183
# positive
# 'shouri' not in training corpus; ignoring.
# 'famous' not in training corpus; ignoring.
# [0.26923367 0.40918198 0.32158434]
# 0.40918198
# neutral
# 'packag' not in training corpus; ignoring.
# [0.13327055 0.3798764  0.48685303]
# 0.48685303
# positive
# 'submit' not in training corpus; ignoring.
# 'lfc' not in training corpus; ignoring.
# 'complic' not in training corpus; ignoring.
# [0.47744232 0.1484532  0.37410453]
# 0.47744232
# negative
# [0.0707325  0.83922476 0.09004271]
# 0.83922476
# neutral
# [0.11444733 0.59511745 0.29043528]
# 0.59511745
# neutral
# [0.08334702 0.06453855 0.85211444]
# 0.85211444
# positive
# [0.25031954 0.48172793 0.26795253]
# 0.48172793
# neutral
# 'wicker' not in training corpus; ignoring.
# 'lantern' not in training corpus; ignoring.
# 'bemmi' not in training corpus; ignoring.
# 'lantern' not in training corpus; ignoring.
# 'ion' not in training corpus; ignoring.
# [0.11045714 0.44669083 0.44285202]
# 0.44669083
# neutral
# 'restor' not in training corpus; ignoring.
# 'democraci' not in training corpus; ignoring.
# [0.11579413 0.5025111  0.38169482]
# 0.5025111
# neutral
# 'peni' not in training corpus; ignoring.
# [0.16411795 0.5916868  0.24419522]
# 0.5916868
# neutral
# [0.01671731 0.06671315 0.9165695 ]
# 0.9165695
# positive
# [0.41893676 0.3416584  0.23940478]
# 0.41893676
# negative
# 'earthquak' not in training corpus; ignoring.
# [0.07682398 0.6169868  0.3061892 ]
# 0.6169868
# neutral
# [0.07468958 0.6441491  0.28116122]
# 0.6441491
# neutral
# [0.04005986 0.05123314 0.908707  ]
# 0.908707
# positive
# 'commenc' not in training corpus; ignoring.
# [0.11425674 0.5000702  0.38567302]
# 0.5000702
# neutral
# [0.14003213 0.5097945  0.35017344]
# 0.5097945
# neutral
# 'geraghti' not in training corpus; ignoring.
# 'heck' not in training corpus; ignoring.
# [0.07976385 0.44206464 0.47817147]
# 0.47817147
# positive
# 'correctli' not in training corpus; ignoring.
# 'contacte' not in training corpus; ignoring.
# [0.12678055 0.59198105 0.28123835]
# 0.59198105
# neutral
# 'desean' not in training corpus; ignoring.
# [0.12657031 0.7285536  0.1448761 ]
# 0.7285536
# neutral
# 'upsid' not in training corpus; ignoring.
# [0.0831642  0.6097757  0.30706003]
# 0.6097757
# neutral
# [0.00869931 0.01806681 0.9732338 ]
# 0.9732338
# positive
# 'nina' not in training corpus; ignoring.
# 'burleigh' not in training corpus; ignoring.
# [0.07532848 0.8390999  0.08557168]
# 0.8390999
# neutral
# 'seth' not in training corpus; ignoring.
# 'mcfarlan' not in training corpus; ignoring.
# [0.07770686 0.76579666 0.15649647]
# 0.76579666
# neutral
# 'holocaust' not in training corpus; ignoring.
# [0.10069533 0.6219608  0.27734384]
# 0.6219608
# neutral
# 'tracker' not in training corpus; ignoring.
# [0.1956897  0.608883   0.19542725]
# 0.608883
# neutral
# 'hhave' not in training corpus; ignoring.
# 'domest' not in training corpus; ignoring.
# [0.14653064 0.33142135 0.522048  ]
# 0.522048
# positive
# 'gsu' not in training corpus; ignoring.
# 'paulson' not in training corpus; ignoring.
# [0.09788445 0.32452112 0.5775944 ]
# 0.5775944
# positive
# 'routledg' not in training corpus; ignoring.
# [0.09727486 0.7355762  0.16714895]
# 0.7355762
# neutral
# [0.11323857 0.20910393 0.6776575 ]
# 0.6776575
# positive
# 'omfg' not in training corpus; ignoring.
# 'omggg' not in training corpus; ignoring.
# [0.15723085 0.5007688  0.34200037]
# 0.5007688
# neutral
# [0.14767243 0.57083607 0.28149146]
# 0.57083607
# neutral
# 'baylor' not in training corpus; ignoring.
# 'evatt' not in training corpus; ignoring.
# 'rbi' not in training corpus; ignoring.
# [0.12532689 0.5505704  0.32410267]
# 0.5505704
# neutral
# 'tragic' not in training corpus; ignoring.
# [0.33367985 0.37264332 0.2936768 ]
# 0.37264332
# neutral
# [0.0453049  0.24884048 0.70585465]
# 0.70585465
# positive
# [0.20844042 0.13430537 0.65725416]
# 0.65725416
# positive
# 'boundari' not in training corpus; ignoring.
# [0.15819354 0.65412873 0.18767773]
# 0.65412873
# neutral
# 'turnup' not in training corpus; ignoring.
# [0.08050355 0.5535497  0.3659467 ]
# 0.5535497
# neutral
# [0.03023577 0.1937955  0.7759687 ]
# 0.7759687
# positive
# [0.05662073 0.76451856 0.17886071]
# 0.76451856
# neutral
# 'ffffest' not in training corpus; ignoring.
# 'dutti' not in training corpus; ignoring.
# 'santigold' not in training corpus; ignoring.
# [0.20023993 0.4916307  0.3081294 ]
# 0.4916307
# neutral
# [0.12547797 0.53472865 0.3397934 ]
# 0.53472865
# neutral
# [0.18893687 0.6120676  0.19899558]
# 0.6120676
# neutral
# [0.00635355 0.00637523 0.98727125]
# 0.98727125
# positive
# 'spiritu' not in training corpus; ignoring.
# 'curzon' not in training corpus; ignoring.
# 'mayfair' not in training corpus; ignoring.
# [0.01572534 0.05405657 0.9302181 ]
# 0.9302181
# positive
# [0.06332856 0.04940045 0.887271  ]
# 0.887271
# positive
# [0.10638127 0.48144    0.4121787 ]
# 0.48144
# neutral
# 'blunt' not in training corpus; ignoring.
# 'boxford' not in training corpus; ignoring.
# [0.3098602  0.44528773 0.24485207]
# 0.44528773
# neutral
# 'bomber' not in training corpus; ignoring.
# [0.05338847 0.04069819 0.90591335]
# 0.90591335
# positive
# 'jacuzzi' not in training corpus; ignoring.
# [0.13363658 0.37952363 0.4868398 ]
# 0.4868398
# positive
# [0.13968301 0.68302405 0.17729299]
# 0.68302405
# neutral
# [0.0611482  0.48371646 0.45513535]
# 0.48371646
# neutral
# 'oblig' not in training corpus; ignoring.
# [0.12420583 0.62498647 0.25080776]
# 0.62498647
# neutral
# [0.09483876 0.20495051 0.70021075]
# 0.70021075
# positive
# [0.06115191 0.38774303 0.551105  ]
# 0.551105
# positive
# [0.14922595 0.50734156 0.34343252]
# 0.50734156
# neutral
# 'brom' not in training corpus; ignoring.
# [0.09773279 0.6852726  0.2169946 ]
# 0.6852726
# neutral
# 'sooooooo' not in training corpus; ignoring.
# [0.02033643 0.01202535 0.96763825]
# 0.96763825
# positive
# [0.13990211 0.19100085 0.669097  ]
# 0.669097
# positive
# 'brood' not in training corpus; ignoring.
# [0.05688766 0.74639684 0.19671552]
# 0.74639684
# neutral
# 'whose' not in training corpus; ignoring.
# 'thiss' not in training corpus; ignoring.
# [0.19449656 0.3607349  0.44476852]
# 0.44476852
# positive
# [0.11075328 0.63888365 0.25036308]
# 0.63888365
# neutral
# [0.12455629 0.5942854  0.28115833]
# 0.5942854
# neutral
# 'migrain' not in training corpus; ignoring.
# 'eyepatch' not in training corpus; ignoring.
# [0.13697396 0.58744526 0.27558076]
# 0.58744526
# neutral
# 'mblaq' not in training corpus; ignoring.
# [0.11143274 0.49791387 0.39065337]
# 0.49791387
# neutral
# [0.15720265 0.25772515 0.5850723 ]
# 0.5850723
# positive
# [0.16592558 0.60875297 0.22532149]
# 0.60875297
# neutral
# 'ibb' not in training corpus; ignoring.
# [0.12395211 0.5633042  0.3127437 ]
# 0.5633042
# neutral
# [0.10094791 0.6868824  0.21216968]
# 0.6868824
# neutral
# [0.1434695  0.3687895  0.48774102]
# 0.48774102
# positive
# [0.15327333 0.63790345 0.2088232 ]
# 0.63790345
# neutral
# [0.1656241  0.36264986 0.47172603]
# 0.47172603
# positive
# 'istrategi' not in training corpus; ignoring.
# [0.11292882 0.5005638  0.38650742]
# 0.5005638
# neutral
# 'firepit' not in training corpus; ignoring.
# [0.08659615 0.37507388 0.53833   ]
# 0.53833
# positive

# %%
count=0
notp=0
notn=0
notq=0
for i in range(len(que)):
    if que[i]==test_y[i]:
        count+=1
    else:
        print(test_x[i])
        print(test_y[i],que[i])
print(count/len(que))
# Out:
# We nail trifecta today check
# 2 1
# morn despertado peusto la mtv estaban hablando de green que bonito
# 2 1
# andi rooney make last appear minut If prove
# 2 1
# think gonna maccyd breakfast way spur tomorrow
# 2 1
# jack welch mort zuckerman alway give busi style part make mess
# 0 1
# edgar david make success return absenc lead barnet leagu win vs
# 2 1
# the sun shine cornwal perfect walk padstow grab rick fish chip way
# 2 1
# busi prepar mini masterclass studio decad chocol ganach tort welcom good
# 1 2
# sweet parti n saw someon look like song too younger
# 0 2
# wednesday go suck even plan go work
# 0 1
# michael just hear green time sinc leav florida burst I penderg
# 0 2
# activist demand releas jharkhand tribal new nov condemn arrest woman
# 0 1
# pist I might abl go volleybal game tomorrow
# 0 1
# bomb squad bake sale thursday miss
# 2 1
# thing know the postal brink default
# 0 1
# monday town richi hawtin loco dude tix still avail
# 2 1
# wit perfectli execut crash land gulf mexico
# 2 1
# Aw hell curti painter come give
# 0 2
# I march get mlk day recogn holiday mind I old I
# 1 2
# trayvon touch shoulder period tri hide like lmfao see tall ass
# 0 1
# jacksonvil realli sound like move tomorrow
# 1 2
# dematha shock gonzaga can stag regroup time wcac
# 0 1
# first day film danc ice
# 2 1
# hello tomorrow play the button onstag come regret
# 2 1
# In Do I wanna see toni peter starcatch paul rudd stage
# 1 2
# sit home saturday night watch silent hous xP
# 0 1
# toni gonzaga smile video I swert ni may pic toni
# 2 1
# may goin down throw graduat At mardi gra winchest RD suit pm
# 2 1
# I go chapel hill tomorrow still contact find damn speech I hate
# 0 1
# harold purpl although may slightli and anyth seuss alway
# 1 2
# when say sunday night offici last day march
# 0 1
# today rare day democrat get healthier club growth scorecard
# 2 1
# Ps sit roger johnson restaur look like up drug abus crack judg look
# 0 1
# playwright mel make today due So I guess gotta eat birthday
# 0 2
# the fox show watch move onto georg clooney thank I may one planet never watch titan
# 1 2
# thi time tomorrow night ill parti chapel hill
# 2 1
# I want go school monday My excus hisd school lol
# 0 2
# I type bazura googl imag imag photo also glenn moustach
# 1 2
# what heck obama year democrat control
# 0 1
# dongwoo get scare whole thi like time get scare staff film lol
# 0 2
# correct march band cancel world wld think common sens cancel school earli
# 0 1
# beer chicken watch till work hour mayb reserv nicknam might fun
# 2 1
# I pass looper pico rivera messag text want
# 2 1
# TV time still wait call itv danc On ice start think I may too
# 0 2
# watch last hipster may greatest charact sinc stevi eastbound
# 2 1
# If rampag game DM I may abl get
# 1 0
# help bia infinit gonna
# 0 1
# whi one put youtub video todd bertuzzi assault steve moor ipad penalti
# 0 1
# RT have hear epic new adventur terra nova come trailer
# 1 2
# thi creator holi come ignit fireston surrend
# 1 2
# sandi pass cathedr close lightli touch nc open
# 2 1
# So In flame come back decemb lamb coupl day dethklok come black dahlia murder
# 1 2
# although take wednesday repeat big brother
# 1 2
# highlight day buy ticket see ferri corsten marku schulz novemb
# 2 1
# concert back eng kick sit morn
# 1 2
# So far today ive ask win rugbi world cup score would
# 1 2
# you definit start flacco We talk
# 1 2
# senran kagura PS vita may advanc breast physic system complet costum destruct compar
# 2 1
# hey forget show rex theatr anyon want ticket contact
# 2 1
# pitch darn well holiday rick dinner tomorrow see week
# 2 1
# I grow oak lawn like reason citi wife job
# 1 2
# think your affection worship lead effect nugget
# 2 1
# mvp chri paul man jason terri defens player iman shumpert most improv paul georg coach year georg karl
# 1 2
# ani joey fan want cover nn win may take
# 2 1
# thursday night bay buccan V minnesota vike vimeo home video
# 2 1
# RT ladi gaga rest night concert I
# 1 2
# mav beat laker tomorrow accept bet
# 2 1
# premier leagu team walcott make seventh appear season sagna also featur
# 1 2
# miss free sunset blue concert tonight march fourth march band
# 1 2
# NO youth come fall sunday high school attend main servic adult super
# 1 2
# meet man make documentari defend joe may look
# 1 2
# So I think yesterday think today littl like movi grind hog
# 1 0
# noth say super rugbi EP king get releg wait
# 0 2
# you attend champ top roller derbi team play indianapoli
# 2 1
# francesco totti think roma unabl catch juventu want side aim season
# 0 1
# gavin henson look set miss rugbi world cup disloc bone right wrist yesterday
# 0 2
# back norwich citi centr wednesday night I hope look honour halloween
# 1 2
# the winan sing they still get
# 2 1
# PJ harvey ha nobodi deserv new album
# 2 1
# cathol give stuff jew fast presbyterian start feel like
# 1 2
# richi hawtin monday night buffalo town ballroom miss
# 2 1
# Hi count day Im back UK go see lfc nufc sunday season ticket seat the
# 1 2
# night parker oh boy
# 0 2
# I buy ticket
# 2 1
# yall shld come n greensboro NC it still go tomorrow fuk w
# 1 2
# watch time emot smh
# 0 1
# nikki walker miss rugbi world cup account knee injuri sustain yesterday v detail
# 0 1
# tonight test one nuit blanch nuit blanch come what
# 1 2
# sonic ost worst place
# 0 2
# RT moment last elect I prepar mind year may god help nigeria
# 0 2
# My miami heat go demolish new york knick I new but sorri
# 2 0
# australian igo one direct premier nickelodeon juli x
# 2 1
# the hottest open mic team hottest organ you want leave join us next friday
# 2 1
# wear makeup sinc ash like anymor
# 0 1
# aww celebr day thursday go jennif hudson though
# 1 2
# On way airport min sleep burn like true
# 1 0
# realli rememb I think start win end chimenti
# 1 2
# On modern sofia yell run omg I laugh like never
# 2 0
# and tampa run version option pass wsh kill us rglll davi may
# 0 2
# the big L strictli gunplay I run thru church n pistol whip priest everi damn
# 0 2
# listen hour expans interview poet frank walker present work murray state novemb
# 2 1
# tomorrow night chanc slay dragon old
# 2 1
# I walk trina fill u write full pg progress note
# 1 2
# gonna watch rest X factor tomorrow caus I keep cri everi time mention take
# 0 2
# bjp drama hide say minist the govern tuesday accus bharatiya janata parti
# 0 1
# damn I wanna get tomorrow harri feel control outtak video break
# 0 1
# all democrat respect race move face recal republican state senat august
# 2 1
# elimin diet start tomorrow mean
# 2 1
# lol laguna ima hollywood day today tomorrow
# 1 2
# watch monday night footbal tonight intro hank william start I
# 1 2
# No market broadcast tonight espn game time
# 1 2
# I may go grid till keep drive pregnanc rape
# 0 2
# krul put craig gordon britain expens keeper without
# 0 1
# big game away vs knick person think knick first msg sandi
# 2 1
# may man crush like someon natur tht laurel tavern
# 2 1
# day duti resum see guy cafe juan
# 1 2
# wrap jersey shore commerci fist pump day
# 1 2
# My suicid note would pictur mark martin I keep wallet
# 0 2
# back norwich citi tomorrow load shop fit
# 0 1
# about auto product may end cmie automobil take
# 2 1
# latest bedroom E L shade may supercharg
# 0 1
# desper need girl cart wait true blood tomorrow
# 1 2
# and big time rush saturday count haha
# 1 2
# woodi go anoth mail monday fp russia caus last one hilari far
# 2 1
# eat feel guilti goin hour AZ go tri make life better
# 0 2
# nicki miinaj talk robin robert good morn nicki minaj perform good morn america
# 1 2
# On sunday watch sarah G one dream come true togeth song number sarah
# 1 2
# tomorrow the winan heart heavi wonder need hear
# 2 1
# review hit write initi impress My gener tip big android
# 0 1
# what team think may get I see sacramento
# 1 2
# iqaluit iqaluit without drink scream saturday morn depress
# 0 1
# It need storm februari endymion get cancel parad would start
# 0 1
# laura gareth noah stewart margherita taylor attend classic brit award septemb
# 1 2
# somehow eyeshadow smear center I look like particip ash and I pull chunk eyelash
# 0 2
# and harri redknapp distanc job follow specul plan talk
# 0 1
# My dad reckon nigeria presid would issu shoot sight order sinc
# 1 2
# off scotland today week miss wankfest utd
# 0 2
# So I hear old crush go bell game tomorrow wanna
# 0 1
# strip club owner make time much get plenti they take poor
# 0 2
# nine goa congress legisl want join oct rule bharatiya janata parti
# 2 1
# just whip whip night soul train may never
# 2 1
# I think I may person around excit beyonc half time perform
# 0 2
# have littl trip old town could easili mexico off vega get monday
# 2 1
# doe everyon realiz voic Ie cassade pope sing sign band hey Or dia half meg
# 0 1
# two birthday one jelli I wonder kind birthday cake one goodnight
# 1 2
# littl My dad ask silva fight I repli minut later dad
# 1 2
# droid bionic seemingli clear may final head glori
# 2 1
# final destin open tell us closest brush death chanc win pair
# 1 2
# the mta cost less I think I wait and pretti freak hot
# 0 2
# call I call sorri carter IV august hellllll
# 2 1
# A littl old ladi answer knock door one confront
# 1 2
# need go februari mardi gra No beauti
# 2 1
# last chanc see silent hous drink tour london tomb tomorrow enter
# 2 1
# the wizard summer leagu team last rd includ overal last yr theyr lose D leagu
# 0 1
# world there good n real ppl n fake I realli feel jlin make durabl like yao
# 0 2
# marijuana law washington pass
# 2 1
# I hear pink friday get tire hear canon brag success
# 1 2
# yah I know but keep say monday night footbal say mnf confus bc thursday
# 0 1
# girl night fairfax polic gym revercomb potluck follow
# 1 2
# RT where everyon watch raven vs eagl game thi what
# 2 1
# who readi parti march fourth march mthd saturday night gothic
# 2 1
# obsess star war right treat I let watch famili guy tonight
# 1 2
# I abl look todd bertuzzi way sinc steve moor incid
# 0 2
# RT prepar mark independ day befit manner august full A
# 2 1
# Im mad cathol im go baptist church tomorrow convert
# 0 1
# I hope melissa mccarthi get emmi
# 1 2
# pray NO one get hurt OR kill IN london tonight thi look like gonna go
# 0 2
# amanda knox win anoth round amanda knox skirmish today appeal murder
# 1 2
# I fail see ram play twice mnf div game isnt til
# 0 2
# come see david taylor pivopivo tomorrow night
# 2 1
# steve job biographi may avail time ipad
# 1 2
# all need ryan leaf get RT aaron kurt warner kyle kendrick the jungl
# 2 1
# tragedi strike collid sport world mikel leshour blow wa lion fantasi
# 0 1
# how footbal sunday turner big littl
# 1 2
# oct eunha icn nanj look like fish feel possess
# 1 2
# next papa front basebal I ask playoff start
# 2 1
# wish I could go church I realli
# 1 2
# dmdk parti lead actor vijayakanth may sustain long time shrewd polit
# 0 1
# play jacinto guardian fer time nd rain
# 0 1
# watch good time I think I alreadi know tht movi gonna turn smh
# 1 2
# need loo sinc bethnal now side romford thi suit might get dri clean tomorrow
# 0 1
# RT good voter go poll two final
# 1 2
# RT rememb vote consid practic recal practic make
# 2 1
# silent hous stranger call woman black ass friday also ass
# 0 1
# tour start show start side bar Go paradis solid gold
# 1 2
# how much want win enough ralli last day lynchburg
# 1 2
# espanyol vs barcelona septemb min barca score pen last minut win
# 2 1
# will lunch tomorrow hoe hit castl
# 0 1
# mention flatbush be go concert
# 1 2
# I tell shane would get rival sign
# 1 0
# henryvil resid still wait help march
# 1 2
# all cowork go reason I may go
# 1 2
# RT there parti usa tonight parti worldwid miley tcaformiley
# 2 1
# never start work dream goal never mean anyth act
# 2 1
# just watch whole season breakout king find cancel fuck show
# 0 2
# X may hv ppl hv idea except make bomb killem
# 0 1
# Hi My korea like US presidenti elect decemb
# 1 2
# readi go lexington game tomorrow
# 2 1
# di u download epi eng sub may I know websit
# 1 0
# tonight colt fan go say man john beck
# 2 1
# you know call japan rise everyon squint day
# 2 1
# how I miss today nation margarita kinda go ash
# 0 2
# want limit impress while stage roubaix
# 2 1
# envi everyon go big bang show tomorrow
# 1 2
# tom boonen summon man poll station mol If get fine
# 0 2
# kevin rudd talk PM betray sunday oct senior labor mp bat divid
# 0 1
# wichita error I imagin veteran coach gene stephenson boil msu lead bottom
# 0 2
# next person comment win ticket tonight tomorrow colt game mcallen
# 2 1
# last night lloyd A sad day miss deep
# 0 2
# two oscar die know I guess stand till novemb
# 0 1
# bout listen nicki minaj night
# 1 2
# the princ announc someth ocean north canada qia He also meet mayor
# 1 2
# god daft He bright she appar sit wash ignor
# 0 1
# older brother go see tenaci D sunday dave grohl go play drum
# 2 1
# rock okinawa stylish airport On octob
# 2 1
# carter IV let fuckin go
# 2 1
# australian captain michael clark team loui vuitton special cricket trunk design herald
# 2 1
# sinc busi day just kill
# 0 2
# unfortun I get tune saturday kitchen
# 0 1
# Is evil laugh grader read short least five mistak name
# 0 1
# surpris major sit window get wanker
# 2 1
# look go tri Do base colour two coat northern light
# 2 1
# pineappl mango get work head ritz carlton sunday brunch
# 2 1
# last tuesday ask greatest england captain winner steven gerrard place bobbi moor
# 2 1
# I realli hate think type thing happen miami could happen alabama
# 0 1
# I doubt come jerusalem and
# 1 2
# adm I may crazi look like japan quit delet
# 1 2
# one ticket leave game miss rematch nfc championship game NY hit
# 2 1
# lower rim may one thing turn off My attract wbb nba fundiment
# 1 2
# off bed sexi Mr tomorrow morn watch galveston come make jello shoot
# 1 2
# yeah pretti sure go selma
# 2 1
# brrrr shock windi feel chilli sun We colder siberia
# 0 1
# mail cesc fabrega desper leav arsen barcelona offer give
# 0 1
# listen poetic justic time
# 1 2
# As patient awaitrt back studio put final touch nxt week
# 2 1
# I think need first XI readi player huge ask unless prepar overpay
# 0 1
# go annual hate kickbal tournament soccer field right
# 1 2
# ill go ticketek tomorrow su
# 2 1
# cof someon go germani novemb I realli envi
# 2 1
# tiffani one mc along yonghwa gikwang sb kpop super concert novemb
# 1 2
# No I get spc hire young eli go entertain white folk monday night
# 0 2
# just finish watch
# 1 2
# forget soup thank saturday
# 0 2
# thi excel the box goodi show studio
# 2 1
# tough one tonight play hard come short loss davi score lone La rong tomorrow
# 0 1
# sad month wait time still mean hrt would
# 0 2
# go see kendrick lamar jan
# 2 1
# okc thunder center kendrick perkin may miss preseason due wrist injuri
# 0 1
# may run olymp balanc book I learn I know econom simciti
# 1 0
# monday night footbal wrangler game time wichita get ticket
# 2 1
# I rememb In what
# 2 1
# biggest name music entertain and ricki who click
# 2 1
# march official nation bieber day get day
# 1 2
# tressa libbi split today meet tomorrow like alot like
# 2 1
# ecuador worri health ecuador say concern health wikileak
# 0 1
# not abl watch enril sens like inq
# 0 1
# someday parti name ye I turn sixteen colleg student
# 2 1
# kill sadat reason egyptian struggl may face uncertain futur
# 0 1
# To anyon plan watch teen choic award spoiler the winner justin bieber
# 2 1
# watch In thing I say order snapback jay
# 1 2
# realiz spend super bowl last two birthday either comput
# 0 1
# full you read sun sign aqua pisc
# 1 2
# music A girl like good girl go rate talk that talk final
# 1 2
# I turn perform ruffin due venu serv bro
# 0 1
# appl ceo apolog new map app appl ceo tim cook apolog friday
# 2 1
# pleas love holster buy feb wppi fray mani urgent need help oct wed ta
# 1 2
# bear februari close through heart pain I still look love guess imma alway b crazi
# 0 2
# get readi head pico rivera meet stylist tri get look togeth tomorrow
# 1 2
# the nicest teacher world give us extra day hw I still guess wake earli
# 2 1
# So london studio tomorrow hope one mention brit award error
# 1 2
# taylor swift grammi LL cool new oct taylor swift choose present
# 1 2
# go ace paper merci
# 2 1
# bday tomorrow spend natchitoch away
# 0 1
# pakistan approv liberalis visa accord india nov pakistan approv liberalis
# 2 1
# not convinc hay v chisora fight upton park rather see carlton cole v emil heskey
# 0 1
# A celebr offici open our hour
# 2 1
# yesterday day atom bomb I embarrass moment silenc first
# 0 2
# tryna prepar concert two greatest artist
# 2 1
# half match take yellow card scar still proud calf
# 2 1
# even power point tok want anyth chang
# 0 1
# dont care carl save yeah lose also wont cri night long wednesday
# 0 2
# let vote andrew show do not die A vote vote andrew
# 2 1
# that kind year river fantasi time
# 1 2
# I fux wit yo choic gift hand ben carson alex autobiographi malcolm X top
# 2 1
# easili thi club think brewer may upset appl cart win NL
# 0 1
# wise word kristin know leav may smartest thing ever learn
# 2 1
# first time list diva think avril
# 2 1
# go big sean concert tomorrow liacoura
# 1 2
# today world music william fire grand ole opri tell return
# 0 1
# hell yea lmfaoo see tomorrow asia babi
# 2 1
# our coverag garner athen drive be tomorrow night hope join
# 1 2
# anni finish high water mark ash wed bayford oyster Co
# 1 2
# honesti often best fabio russia hope injuri seriou play
# 0 2
# somewher steve job spit morn coffe onto comput
# 0 2
# sun bird sing nirvana track I bring
# 2 1
# golf camilla parker bowl and U hear go order
# 1 2
# last day bca say ye dress breast
# 0 1
# In pari mosh far away see pit fail
# 0 2
# I jet end wish keep sam gagner
# 1 2
# I forget sad first episod season dexter
# 0 2
# I hope peopl like inbetween
# 1 2
# If call one time may find scold hot coffe head toward crotchal
# 0 1
# just finish rehear readi kendrick lamar show shout out
# 1 2
# I do homework past I know lyric wya nandito ako heart
# 2 1
# I get cougar town cupcak go bring tomorrow I eat
# 0 1
# thi may reason io mani daft desol wasteland come
# 0 2
# ya august novi sad silicon soul
# 1 2
# crime women panel meet oct It would first time haryana khap panchayat nation
# 1 2
# RT Be sure catch former owl footbal player lestar jean monday night footbal tonight hou
# 2 1
# refus admit bring groundhog day
# 0 1
# So I ask diehard fsu fan game dook sit kinda worri coach cut coastal divis lead team
# 1 2
# whi wait septemb see stan walker sydney come newcastl panther
# 1 2
# No pottstown game togeth davi
# 0 1
# anderson cooper kristin chenoweth hi come anderson live premier
# 1 2
# love like michael nose never understand
# 1 2
# may know spanish shit whenev listen IL divo want flash
# 2 0
# with franki feel like forget let know never forget
# 0 1
# sister rub face fact school tomorrow I thalia it love though lmao
# 0 2
# now sun iguana
# 2 1
# well I figur get comput make the boy help us hahaha
# 1 2
# aww im piss caus cant download unbroken youtub anymor im also go cinema tomorrow
# 0 2
# travi take sit
# 2 1
# free psn game psn game zen pinbal free game playstat As oct get usa psn
# 2 1
# can anyon help univers I worksheet due tomorrow I honestli not figur
# 0 1
# asia stock mostli china asian stock market advanc friday batch upbeat econom data
# 2 1
# tomm sunday not sure go No power NJ
# 0 2
# long day unpack turner now movi knit saturday
# 1 2
# want depress rl folk daili mail report sellout eng v fiji twicker sit broader vision deeper
# 0 1
# go taiwan soon train pass decemb look forward ha
# 1 2
# rumour nokia come
# 1 2
# knick vs celtic take melo gonna watch yanke guess look like sport saturday
# 1 2
# the raider need repres
# 2 1
# I saw church sunday tohs david ruffin glass fli
# 2 1
# I miss QT get remind watch stevi TV everi I
# 0 2
# RT I find barcelona real madrid play I need sleep
# 0 1
# crew den univers calgari cheer u next Go stamp
# 2 1
# read the sun watch jeremi where go better
# 0 2
# sunday turn day play templ social life joke forev alon lvl
# 0 2
# So u tx ask I spend I even know U hart haha
# 2 0
# look like sport team owner r studi congression lock
# 1 2
# melissa mccarthi margo ani
# 2 1
# turn oliv dinner tonight tomorrow like dinner tonight later
# 2 1
# whi oh nuit blanch night wed I
# 0 1
# Im get twitter tomorrow TL consist bunch girl talk justin beiber
# 0 2
# boi you best BE AT rim tomorrow lol like one go lol I realli dont wanna go
# 0 2
# anonym would chanc see topless
# 1 2
# not bad payoff race trifecta check
# 2 1
# I see blame case creighton pick win siu pick finish ahead UE
# 0 2
# yeah wha your topic seem interest lol shit malcolm but ima
# 2 1
# time russia win big match russia manag fabio capello thursday say intend
# 1 2
# YM shit right finish listen I Am not A human go onto pink hello careless
# 1 2
# go florida back tuesday trash room
# 2 1
# see guy octob bathurst along stan
# 2 1
# just meet player roger johnson fella walk around like own So I debag flick
# 0 2
# I cri dead badger name shreddi anim anoth tough friday
# 0 2
# whatev plan may beauti
# 2 1
# concert dalla success hot church then back
# 2 1
# dirti footbal team mnf tonight
# 0 2
# DM number send pic dress wear perfect black
# 2 1
# buck see machin all that the black dahlia I may go see show witho
# 1 2
# obama weak could do alon ammend know congress would block
# 0 1
# kerri help famili long beach If anyon non
# 2 1
# august wa day I meet I regret take pictur miss go SS
# 0 2
# sinc ET go via bkk freedom right indirect
# 1 2
# good hong meme pa ang kasama may headach jap resto lkf
# 1 2
# charger may go make playoff nfc team must win
# 1 2
# art Do think nyc host marathon would soooo mani desper need respect
# 0 2
# ynm do see top ten best play
# 1 2
# saturday I buy ticket
# 2 1
# break time tomorrow second I would alreadi gari carter
# 1 2
# somehow I manag princess leia bra go noel gallagh ie
# 1 2
# So proud alma mater host debat debat univers denver
# 2 1
# sign day friday hate school I love senior
# 1 2
# how think time anoth deu Ex playthrough releas friday
# 2 1
# pump open season tomorrow night
# 2 1
# RT trend worldwid thi not someth proud unit sort
# 0 2
# mushu the hurrican wear rockstar bday foam guitar show last We kill
# 2 1
# occur I receiv residu check nearli year I think I email sag
# 0 1
# On tha real I care never go school young definit go all citi tomorrow
# 2 1
# ive realiz minotaur compani consist mostli pred vindic lol
# 1 2
# and team take dump round big KU flame mizzou lose northern
# 0 2
# iranian gener say iron dome deal missil talk like may end find
# 0 1
# make feel better cbc nation featur kinder morgan pipelin wednesday
# 1 2
# tiger wood luckili terribl golf go see tgc today cb everyon
# 0 2
# tire I may watch end zombieland tallahasse spirit anim
# 1 0
# I strong dislik georg I realli whi wait sentenc
# 0 2
# dalla star forward jami benn sign hamburg freezer He could make debut mannheim
# 1 2
# seem new ipod like kasabian laptop crash everi time get sync time
# 0 1
# martin atkinson refere If one shock tackl
# 0 1
# hey david nice along how
# 2 1
# how go kill u da episod new season breakout damn eye miss
# 0 1
# one main influenc album michael No
# 1 2
# rum chata hot thin thi saturday
# 2 1
# I record the want celebr juic anyon miss stream saturday anyon want see
# 1 2
# thi bitch put frog back lmfao throw back thursday
# 0 1
# I realiz bellami freshman QB play select leav lot option toss
# 0 1
# with win last norfolk admir tie american hockey leagu record consecut fantast
# 2 1
# go georgetown game
# 2 1
# fab jason Wu satin scarlet clutch off whoop
# 2 1
# the pacer count paul georg step gerald green DJ augustin nat
# 1 2
# kurt may drug possibl root beer find after murder
# 0 1
# verland possibl ahead so better CC bounc back last out like alway
# 2 1
# ladi gaga fear lo nov singer ladi gaga still touch peopl
# 0 1
# follow take morgan state today Be realli bore cuz your choic
# 0 1
# think run australia day weekend Is good bad
# 1 2
# I DO get pjob bristol espn yall gotta come parti I would let yall know night
# 1 2
# acta choo get throw give tie run chanc come
# 0 1
# goal lead us world absolut
# 0 1
# luna take break perfect major aspect meet jupit tomorrow morn
# 0 1
# interview kfc fuck go understand singl work say hardli understand interview set
# 0 1
# I get readi master class I teach wppi come tuesday go
# 1 2
# forget mitch daniel go steven show think come
# 1 2
# depend unoffici your may seem progress too bad lead suppli heat
# 0 1
# son I saw hous last night mil behind hella tree look like palac aladdin bullshit lol
# 1 2
# go go see magic mike jeff timmon thing next
# 1 2
# A crash earli sunday morn claim life selma jame brandon
# 0 1
# one million peopl march london past six but care tottenham tonight
# 0 1
# open sourc misconcept IT south africa may five year behind rest world
# 0 1
# just read timmonsvil beat crap mcbee still
# 0 2
# open today cowboy alien rememb super saver
# 2 1
# trina stop support day I find thibodaux showcas lol
# 0 2
# flight denzel washington come tomorrow
# 1 2
# watch brilliant rick stein make paella saturday kitchen
# 1 2
# cakap can tuesday Im I realli want may copi past
# 2 0
# strawberri festiv late
# 2 1
# thank St david park home game
# 2 1
# gonna fight think ima wear warrior gear tomorrow lol
# 2 1
# look like beauti night throw brooklyn bridg
# 0 2
# need break come kickbal tournament tomorrow behind
# 2 1
# name date No fuck just call tomb
# 1 2
# too amazon open black friday deal thanksgiv week world seri end
# 0 1
# not sure I want go eng v holland game get ticket coz arsen might featur
# 0 1
# I wear black dahlia murder shirt one sun dress next xD
# 2 1
# campbel must feel like lotteri sit european ben Ba
# 2 1
# okay go elon univers go concert
# 0 1
# get dexter fix until night dexter
# 2 1
# everi time I wear hoodi I think hoodi march and trayvon martin and ppl I know person die
# 1 0
# imma check wait till carter IV drop I make decis like one lol
# 1 2
# bro u gotta see video today I jukin shit raider
# 1 2
# sneak check freebi get cv black link first
# 2 1
# watch muse jonathan ross show last night promptli nightmar screw everyth
# 1 2
# I would think would run It may part job
# 1 0
# nigga laker still gon finish damn near first yo team struggl spot
# 0 1
# morn I want watch vampir
# 0 2
# do seriou suck tonight I go tomorrow
# 0 1
# I may splurg A celebr joss
# 1 2
# I realli want tweet sinc I buy ticket concert octob irv plaza nyc
# 2 1
# sportsnat wont let jeremi evan dunkfac thi time ive see still funni though
# 2 1
# In sport world kenseth avoid pileup win daytona winner matt kenseth sunday
# 1 2
# prepar steve job us tweet I hope enjoy day see
# 1 2
# you hit com Do role show echo just enter last contest I could
# 2 1
# I issu drive So im gonna tri make AZ LV
# 1 2
# guilt well TV footag suarez punish strength
# 0 1
# I sing tomorrow winan class tell I sound like brian get
# 1 0
# It seem like nation kiss day everi who tf make shit
# 0 1
# I need go find anoth hour day march band tomorrow
# 2 1
# wors thing saturday morn the omelett challeng pointless annoy even jame martin look
# 0 2
# take cant buy size soft freedom
# 0 1
# the intern committe red cross friday warn three palestinian hunger striker
# 0 1
# aglin nebraskan may notic our best logo locat across state
# 1 2
# I realli want go iss
# 0 2
# they stop film and I still find alan film movi La
# 0 2
# and appar also nation bieber day well St day
# 1 2
# I realli want tweet sinc I buy ticket concert octob irv plaza nyc
# 2 1
# amanda knox lie repeatedli clean bleach morn innoc petal
# 0 1
# Im zan lean nun iren today band camp ju laugh poo ass freshman snare drummer
# 0 2
# shout boy fight tomorrow night la vega put work I need wish
# 2 1
# funni ask We leicest squar theatr octob perform edinburgh final
# 2 1
# jet fli low hous give tingl onli week go I take but
# 2 1
# take litr flavour water bed super sunday gonna result mouth like flip
# 1 2
# I dream vampir diari last
# 1 2
# treat cookout first thing I get
# 2 1
# centr suffer alleg jayalalithaa tuesday charg upa
# 0 1
# I run marathon sunday hair bright pink
# 1 2
# US footbal chardon tonight Q
# 1 2
# If world end find justin beiber castrat I
# 0 1
# appl ceo problem new septemb
# 0 1
# guy fix dont want end diablo iii
# 0 1
# who want parti tay I saturday night real
# 2 1
# walk past girl throw gut outsid bu averag monday night
# 0 1
# compla allll dam not like ME sinc I wa IN grade parker ha be MY main babi
# 0 2
# In honor remembr tom hagedorn support soccer tomorrow take
# 2 1
# cover global marijuana march night day fewer seriou
# 1 2
# He year leave deal resist may where predict espanyol
# 0 1
# nokia nine By ian post juli global the nokia So fast regular
# 2 1
# get leonardo da painter court milan come
# 1 2
# It I fli NC I pray uppc famili awesom time
# 0 2
# It must thursday everyday cuz nigga thirsti time
# 1 2
# RT one thing learn live detroit nigga pull gun get fuck crazi ass night
# 0 2
# gotta hold dub flatbush zombi show throw blunt stage
# 2 1
# In case forget panther horribl rank run top CB
# 0 1
# It straight round submiss straight minut miesha tate go get
# 0 1
# crazi sport econom larri rooki deal M pick damian lillard make M
# 1 2
# RT go arsen ladi v everton nervou
# 0 1
# stop dook even sun shine
# 0 1
# thi may end benefici us cofield play natur end spot baker clog
# 2 1
# jim luxford east york calendar daili winner septemb
# 2 1
# RT red philli fli high take yanke giant CC hamel
# 2 1
# club basketbal game AT gonzaga rudolph fit center court novemb spread word
# 2 1
# the winan smash hit cool without more whitney
# 2 1
# like omit the vaccin top move kasabian the enemi drop tell I
# 0 1
# friday night here brownsvil match hanna eagel rivera
# 2 1
# notic go tampa tomorrow want see metormix tampa bay featur
# 1 2
# friday nite dwc read raid sound dvd CD cruis home raphael friday note
# 1 2
# may bjp defend As shouri famous cong bjp one
# 2 1
# look edit the record full packag photo plane crash
# 1 2
# arsen submit bid even scott look like move lfc I talk may turn complic
# 1 0
# episod famili guy tonight put slight smile face
# 2 1
# charli sheen seem pretti upcom He actual seem like I may
# 2 0
# just case need inspir steve stanford commenc via
# 2 1
# make pleas parti differ game
# 2 1
# denzel washington brian geraghti gear one heck ride exclus clip see
# 1 2
# desean jackson suppos train camp eagl lock extend mike
# 0 1
# readi long drive boro If past present gsu better paulson
# 1 2
# RT omfg britney like along nicki omggg concert tomorrow thi
# 2 1
# spell name hell infinit
# 0 1
# So sad hear pavol demitra khl tragic pass plane crash absolut terribl
# 0 1
# rock A free show liacoura center thi come watch get
# 1 2
# then make first career field goal edmonton novemb what
# 2 1
# just find new season vampir diari come sept
# 2 1
# feel oblig discuss live larg brighton pleas use direct
# 2 1
# you three day sunday last day swim fairground pool
# 1 2
# ye nufc vs west brom live newcastl unit back ST jame park time
# 2 1
# I want watch the guess whose gonna watch tomorrow thiss girl
# 1 2
# migrain sinc saturday blood vessel burst yesterday eye ani rock mari colvin eyepatch
# 0 1
# hello mexico when mblaq come visit mexican true go brazil septemb
# 2 1
# mick jagger centr sunday u still make
# 1 2
# ok remind convo march brook beat devon alexand world and khan still glass chin
# 1 2
# our beauti new firepit time friday night journey mysteri
# 1 2
# 0.6188760806916427

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(train_x,train_y)                  
clf.predict(test_x)
print(clf.score(train_x,train_y))
